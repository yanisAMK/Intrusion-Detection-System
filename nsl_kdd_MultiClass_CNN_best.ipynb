# %% [markdown]
# NSL-KDD Multi-class 5
# ---
#
# Accuracy: 0.9757184750733138
#
# Precision: 0.9760675860882271
#
# F1-score: 0.9758048763891708

# %% [markdown]
# #Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #Data

# %%
features = ['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot',
            'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations',
            'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate',
            'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count',
            'dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate',
            'dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate',
            'dst_host_srv_rerror_rate','class','difficulty_level']

# %%
from google.colab import drive
drive.mount('/content/drive')
train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/KDDTrain+.txt", names = features)
test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/KDDTest+.txt", names = features)

print(train_df.shape)
print(test_df.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (125967, 43)
# (22549, 43)

# %%
#combining train and test files (there's an error when doing the one hot encoding)
data = pd.concat([train_df, test_df])
print(data.shape)
data.head()
# Out:
# (148516, 43)
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#      class  difficulty_level
# 0   normal                20
# 1   normal                15
# 2  neptune                19
# 3   normal                21
# 4   normal                21
#
# [5 rows x 43 columns]

# %%
data.info()

""" 
  'protocol_type','srevice', 'flag' : categorical types
  'difficulty_level'                : usless
  'class'                           : has multiplie classes of attaks and a normal class
  
  'is_host_login','land', 'logged_in','is_guest_login' : binary no need for normalizing
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148516 entries, 0 to 22548
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148516 non-null  int64
#  1   protocol_type                148516 non-null  object
#  2   service                      148516 non-null  object
#  3   flag                         148516 non-null  object
#  4   src_bytes                    148516 non-null  int64
#  5   dst_bytes                    148516 non-null  int64
#  6   land                         148516 non-null  int64
#  7   wrong_fragment               148516 non-null  int64
#  8   urgent                       148516 non-null  int64
#  9   hot                          148516 non-null  int64
#  10  num_failed_logins            148516 non-null  int64
#  11  logged_in                    148516 non-null  int64
#  12  num_compromised              148516 non-null  int64
#  13  root_shell                   148516 non-null  int64
#  14  su_attempted                 148516 non-null  int64
#  15  num_root                     148516 non-null  int64
#  16  num_file_creations           148516 non-null  int64
#  17  num_shells                   148516 non-null  int64
#  18  num_access_files             148516 non-null  int64
#  19  num_outbound_cmds            148516 non-null  int64
#  20  is_host_login                148516 non-null  int64
#  21  is_guest_login               148516 non-null  int64
#  22  count                        148516 non-null  int64
#  23  srv_count                    148516 non-null  int64
#  24  serror_rate                  148516 non-null  float64
#  25  srv_serror_rate              148516 non-null  float64
#  26  rerror_rate                  148516 non-null  float64
#  27  srv_rerror_rate              148516 non-null  float64
#  28  same_srv_rate                148516 non-null  float64
#  29  diff_srv_rate                148516 non-null  float64
#  30  srv_diff_host_rate           148516 non-null  float64
#  31  dst_host_count               148516 non-null  int64
#  32  dst_host_srv_count           148516 non-null  int64
#  33  dst_host_same_srv_rate       148516 non-null  float64
#  34  dst_host_diff_srv_rate       148516 non-null  float64
#  35  dst_host_same_src_port_rate  148516 non-null  float64
#  36  dst_host_srv_diff_host_rate  148516 non-null  float64
#  37  dst_host_serror_rate         148516 non-null  float64
#  38  dst_host_srv_serror_rate     148516 non-null  float64
#  39  dst_host_rerror_rate         148516 non-null  float64
#  40  dst_host_srv_rerror_rate     148516 non-null  float64
#  41  class                        148516 non-null  object
#  42  difficulty_level             148516 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 49.9+ MB
# " \n  'protocol_type','srevice', 'flag' : categorical types\n  'difficulty_level'                : usless\n  'class'                           : has multiplie classes of attaks and a normal class\n  \n  'is_host_login','land', 'logged_in','is_guest_login' : binary no need for normalizing\n"

# %%
#some stats
data.describe().style.background_gradient(cmap='Blues').set_properties(**{'font-family':'Segoe UI'})
# Out:
# <style type="text/css">
# #T_a9da3_row0_col0, #T_a9da3_row0_col3, #T_a9da3_row0_col4, #T_a9da3_row0_col5, #T_a9da3_row0_col6, #T_a9da3_row0_col7, #T_a9da3_row0_col8, #T_a9da3_row0_col9, #T_a9da3_row0_col10, #T_a9da3_row0_col11, #T_a9da3_row0_col12, #T_a9da3_row0_col13, #T_a9da3_row0_col14, #T_a9da3_row0_col15, #T_a9da3_row0_col16, #T_a9da3_row0_col17, #T_a9da3_row0_col18, #T_a9da3_row0_col19, #T_a9da3_row0_col20, #T_a9da3_row0_col21, #T_a9da3_row0_col22, #T_a9da3_row0_col23, #T_a9da3_row0_col24, #T_a9da3_row0_col25, #T_a9da3_row0_col26, #T_a9da3_row0_col27, #T_a9da3_row0_col28, #T_a9da3_row0_col29, #T_a9da3_row0_col30, #T_a9da3_row0_col31, #T_a9da3_row0_col32, #T_a9da3_row0_col33, #T_a9da3_row0_col34, #T_a9da3_row0_col35, #T_a9da3_row0_col36, #T_a9da3_row0_col37, #T_a9da3_row0_col38, #T_a9da3_row7_col1, #T_a9da3_row7_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a9da3_row0_col1, #T_a9da3_row0_col2, #T_a9da3_row1_col0, #T_a9da3_row1_col1, #T_a9da3_row1_col2, #T_a9da3_row1_col3, #T_a9da3_row1_col4, #T_a9da3_row1_col5, #T_a9da3_row1_col6, #T_a9da3_row1_col7, #T_a9da3_row1_col8, #T_a9da3_row1_col9, #T_a9da3_row1_col10, #T_a9da3_row1_col11, #T_a9da3_row1_col12, #T_a9da3_row1_col13, #T_a9da3_row1_col14, #T_a9da3_row1_col15, #T_a9da3_row1_col16, #T_a9da3_row1_col17, #T_a9da3_row1_col18, #T_a9da3_row1_col19, #T_a9da3_row1_col20, #T_a9da3_row1_col21, #T_a9da3_row1_col22, #T_a9da3_row1_col23, #T_a9da3_row1_col24, #T_a9da3_row1_col25
_col17, #T_a9da3_row4_col18, #T_a9da3_row4_col19, #T_a9da3_row4_col20, #T_a9da3_row4_col21, #T_a9da3_row4_col22, #T_a9da3_row4_col23, #T_a9da3_row4_col24, #T_a9da3_row4_col25, #T_a9da3_row4_col26, #T_a9da3_row4_col27, #T_a9da3_row4_col28, #T_a9da3_row4_col29, #T_a9da3_row4_col30, #T_a9da3_row4_col31, #T_a9da3_row4_col32, #T_a9da3_row4_col33, #T_a9da3_row4_col34, #T_a9da3_row4_col35, #T_a9da3_row4_col36, #T_a9da3_row4_col37, #T_a9da3_row4_col38, #T_a9da3_row5_col0, #T_a9da3_row5_col1, #T_a9da3_row5_col2, #T_a9da3_row5_col3, #T_a9da3_row5_col4, #T_a9da3_row5_col5, #T_a9da3_row5_col6, #T_a9da3_row5_col7, #T_a9da3_row5_col8, #T_a9da3_row5_col9, #T_a9da3_row5_col10, #T_a9da3_row5_col11, #T_a9da3_row5_col12, #T_a9da3_row5_col13, #T_a9da3_row5_col14, #T_a9da3_row5_col15, #T_a9da3_row5_col16, #T_a9da3_row5_col17, #T_a9da3_row5_col18, #T_a9da3_row5_col19, #T_a9da3_row5_col20, #T_a9da3_row5_col21, #T_a9da3_row5_col22, #T_a9da3_row5_col23, #T_a9da3_row5_col24, #T_a9da3_row5_col25, #T_a9da3_row5_col26, #T_a9da3_row5_col27, #T_a9da3_row5_col28, #T_a9da3_row5_col29, #T_a9da3_row5_col30, #T_a9da3_row5_col31, #T_a9da3_row5_col32, #T_a9da3_row5_col33, #T_a9da3_row5_col34, #T_a9da3_row5_col35, #T_a9da3_row5_col3 ...
#   background-color: #f7fbff;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a9da3_row2_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a9da3_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a9da3_row7_col0 {
#   background-color: #99c7e0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a9da3_row7_col9, #T_a9da3_row7_col12 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_a9da3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9da3_level0_col0" class="col_heading level0 col0" >duration</th>
#       <th id="T_a9da3_level0_col1" class="col_heading level0 col1" >src_bytes</th>
#       <th id="T_a9da3_level0_col2" class="col_heading level0 col2" >dst_bytes</th>
#       <th id="T_a9da3_level0_col3" class="col_heading level0 col3" >land</th>
#       <th id="T_a9da3_level0_col4" class="col_heading level0 col4" >wrong_fragment</th>
#       <th id="T_a9da3_level0_col5" class="col_heading level0 col5" >urgent</th>
#       <th id="T_a9da3_level0_col6" class="col_heading level0 col6" >hot</th>
#       <th id="T_a9da3_level0_col7" class="col_heading level0 col7" >num_failed_logins</th>
#       <th id="T_a9da3_level0_col8" class="col_heading level0 col8" >logged_in</th>
#       <th id="T_a9da3_level0_col9" class="col_heading level0 col9" >num_compromised</th>
#       <th id="T_a9da3_level0_col10" class="col_heading level0 col10" >root_shell</th>
#       <th id="T_a9da3_l

# %% [markdown]
# ### fixing labels

# %%
#Actual labels
print(data['class'].value_counts())
# Out:
# normal             77054
# neptune            45871
# satan               4367
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: class, dtype: int64

# %%
#fixing labels

dos_class =["apache2","back","land","neptune","mailbomb","pod","processtable","smurf","teardrop","udpstorm","worm"]
R2L_class =["ftp_write","guess_passwd","httptunnel","imap","multihop","named","phf","sendmail","snmpgetattack","spy","snmpguess","warezclient","warezmaster","xlock","xsnoop"]      
Probe_class =["ipsweep","mscan","nmap","portsweep","saint","satan"]
U2R_class =["buffer_overflow","loadmodule","perl","ps","rootkit","sqlattack","xterm"]

for atk in dos_class:
  data.loc[data['class'] == atk, 'class'] = 'DoS'
for atk in R2L_class: 
  data.loc[data['class'] == atk, 'class'] = 'R2L'
for atk in Probe_class: 
  data.loc[data['class'] == atk, 'class'] = 'Probe'
for atk in U2R_class :
  data.loc[data['class'] == atk, 'class'] = "U2R"

data['class'].value_counts()
# Out:
# normal    77054
# DoS       53387
# Probe     14076
# R2L        3880
# U2R         119
# Name: class, dtype: int64

# %% [markdown]
# ##Data visualisation

# %% [markdown]
# ###Repartition des classes

# %%
data['class'].value_counts().plot(kind = "pie" ,figsize=(5, 5), fontsize=10, autopct='%1.0f%%')
# Out:
# <Axes: ylabel='class'>

# %%
#data.plot(kind='box',subplots=True,layout=(6,8),figsize=(20,40))
plt.show()

# %% [markdown]
# # prétraitement

# %% [markdown]
# ##### 1-Normalisation (Robuste)

# %%
#les colonnes doivent etre numeriques seulement
def normalisation(dataframe, columns):
  normalised_df = pd.DataFrame(RobustScaler().fit_transform(dataframe), columns = columns)
  return normalised_df

# %%
categorical_columns = ['is_host_login','protocol_type','service','flag','land', 'logged_in','is_guest_login', 'difficulty_level', 'class']

# %%
def preprocessing(dataframe):
  #selectionner le valeurs numeriques puis les normaliser
  num_df = dataframe.drop(categorical_columns, axis=1)
  num_cols = num_df.columns
  normalized_df = normalisation(num_df, num_cols)

  #supression des ancienne données numeriques et rajout des données normalisées
  dataframe.drop(labels = num_cols, axis= 'columns', inplace = True)
  dataframe[num_cols] = normalized_df[num_cols]
  df = dataframe
  #remplaces les lables de la colonne 'class": 
  #0 => normal
  #1 => Dos
  #2 => Probe
  #3 => R2L
  #4 => U2R
  dataframe.loc[dataframe['class'] == "normal", "class"]= 0
  dataframe.loc[dataframe['class'] == "DoS", "class"]= 1
  dataframe.loc[dataframe['class'] == "Probe", "class"]= 2
  dataframe.loc[dataframe['class'] == "R2L", "class"]= 3
  dataframe.loc[dataframe['class'] == "U2R", "class"]= 4 

  #onehot encoding
  dataframe = pd.get_dummies(dataframe, columns = ['protocol_type','service', 'flag'])

  return dataframe, df

# %%
normalized_df , df= preprocessing(data)
df.plot(kind = 'box',subplots=True,layout=(6,8),figsize=(20,40))
# Out:
# land                               Axes(0.125,0.77;0.0824468x0.11)
# logged_in                       Axes(0.223936,0.77;0.0824468x0.11)
# is_host_login                   Axes(0.322872,0.77;0.0824468x0.11)
# is_guest_login                  Axes(0.421809,0.77;0.0824468x0.11)
# difficulty_level                Axes(0.520745,0.77;0.0824468x0.11)
# duration                        Axes(0.619681,0.77;0.0824468x0.11)
# src_bytes                       Axes(0.718617,0.77;0.0824468x0.11)
# dst_bytes                       Axes(0.817553,0.77;0.0824468x0.11)
# wrong_fragment                    Axes(0.125,0.638;0.0824468x0.11)
# urgent                         Axes(0.223936,0.638;0.0824468x0.11)
# hot                            Axes(0.322872,0.638;0.0824468x0.11)
# num_failed_logins              Axes(0.421809,0.638;0.0824468x0.11)
# num_compromised                Axes(0.520745,0.638;0.0824468x0.11)
# root_shell                     Axes(0.619681,0.638;0.0824468x0.11)
# su_attempted                   Axes(0.718617,0.638;0.0824468x0.11)
# num_root                       Axes(0.817553,0.638;0.0824468x0.11)
# num_file_creations                Axes(0.125,0.506;0.0824468x0.11)
# num_shells                     Axes(0.223936,0.506;0.0824468x0.11)
# num_access_files               Axes(0.322872,0.506;0.0824468x0.11)
# num_outbound_cmds              Axes(0.421809,0.506;0.0824468x0.11)
# count                          Axes(0.520745,0.506;0.0824468x0.11)
# srv_count                      Axes(0.619681,0.506;0.0824468x0.11)
# serror_rate                    Axes(0.718617,0.506;0.0824468x0.11)
# srv_serror_rate                Axes(0.817553,0.506;0.0824468x0.11)
# rerror_rate                       Axes(0.125,0.374;0.0824468x0.11)
# srv_rerror_rate                Axes(0.223936,0.374;0.0824468x0.11)
# same_srv_rate                  Axes(0.322872,0.374;0.0824468x0.11)
# diff_srv_rate                  Axes(0.421809,0.374;0.0824468x0.11)
# srv_diff_host_rate             Axes(0.520745,0.374;0.0824468x0.11)
# dst_host_count                 Axes(0.619681,0.374;0.0824468x0.11)
# dst_host_srv_count             Axes(0.718617,0.374;0.0824468x0.11)
# dst_host_same_srv_rate         Axes(0.817553,0.374;0.0824468x0.11)
# dst_host_diff_srv_rate            Axes(0.125,0.242;0.0824468x0.11)
# dst_host_same_src_port_rate    Axes(0.223936,0.242;0.0824468x0.11)
# dst_host_srv_diff_host_rate    Axes(0.322872,0.242;0.0824468x0.11)
# dst_host_serror_rate           Axes(0.421809,0.242;0.0824468x0.11)
# dst_host_srv_serror_rate       Axes(0.520745,0.242;0.0824468x0.11)
# dst_host_rerror_rate           Axes(0.619681,0.242;0.0824468x0.11)
# dst_host_srv_rerror_rate       Axes(0.718617,0.242;0.0824468x0.11)
# dtype: object

# %% [markdown]
# #####Data augmentation

# %%
#code to augment some classes
normalized_df['class'].value_counts()
normalized_df['class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
minority_classes = [ 2 , 3 , 4]
mask = normalized_df['class'].isin(minority_classes)
minority_df = normalized_df[mask]
minority_df
# Out:
#        land  logged_in  is_host_login  is_guest_login class  difficulty_level  \
# 13        0          1              0               0     3                15
# 17        0          0              0               0     2                18
# 30        0          0              0               0     2                17
# 33        0          0              0               0     2                20
# 48        0          1              0               0     3                12
# ...     ...        ...            ...             ...   ...               ...
# 22524     0          1              0               0     4                 4
# 22543     0          0              0               0     2                14
# 22546     0          0              0               0     2                17
# 22547     0          0              0               0     2                17
# 22548     0          0              0               0     2                17
#
#        duration  src_bytes  dst_bytes  wrong_fragment  ...  flag_REJ  \
# 13          0.0   1.043165   0.000000             0.0  ...         0
# 17          0.0  -0.093525   0.000000             0.0  ...         0
# 30          0.0  -0.129496   0.000000             0.0  ...         0
# 33          0.0  -0.158273   0.000000             0.0  ...         1
# 48          0.0   1.043165   0.000000             0.0  ...         0
# ...         ...        ...        ...             ...  ...       ...
# 22524       0.0   0.640288   1.073555             0.0  ...         0
# 22543       0.0   3.553957   0.000000             0.0  ...         1
# 22546       0.0  -0.158273   0.000000             0.0  ...         0
# 22547       0.0   0.870504   1.602452             0.0  ...         1
# 22548       0.0   0.071942   0.000000             0.0  ...         0
#
#        flag_RSTO  flag_RSTOS0  flag_RSTR  flag_S0  flag_S1  flag_S2  flag_S3  \
# 13             0            0          0        0        0        0        0
# 17             0            0          0        0        0        0        0
# 30             0            0          0        0        0        0        0
# 33             0            0          0        0        0        0        0
# 48             0            0          0        0        0        0        0
# ...          ...          ...        ...      ...      ...      ...      ...
# 22524          0            0          0        0        0        0        0
# 22543          0            0          0        0        0        0        0
# 22546          0            0          0        1        0        0        0
# 22547          0            0          0        0        0        0        0
# 22548          0            0          0        1        0        0        0
#
#        flag_SF  flag_SH
# 13           1        0
# 17           1        0
# 30           1        0
# 33           0        0
# 48           1        0
# ...        ...      ...
# 22524        1        0
# 22543        0        0
# 22546        0        0
# 22547        0        0
# 22548        0        0
#
# [18075 rows x 123 columns]

# %%
#code--
from imblearn.over_sampling import SMOTE

minority = minority_df.drop(['difficulty_level'], axis = 1)
xm = minority.drop(['class'], axis = 1)
ym = minority['class']

smote = SMOTE()
augmented_x, augmented_y = smote.fit_resample(xm.values,ym.values.astype('int'))

# %%
original_df = normalized_df
xmc = pd.DataFrame(xm).columns
ymc = pd.DataFrame(ym).columns
augmented = pd.concat([pd.DataFrame(augmented_x, columns=xmc), pd.DataFrame(augmented_y, columns = ymc)], axis = 1)
normalized_df = pd.concat([pd.DataFrame(normalized_df.drop(['difficulty_level'], axis = 1)), augmented])
normalized_df['class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ##### Feature selection (reduction) PCA

# %%
normalized_df = normalized_df.drop_duplicates()
normalized_df = normalized_df.sample(frac = 1, random_state = 42)
normalized_df = normalized_df.reset_index(drop = True)

# %%
#Extraction des X et Y
x = normalized_df.drop(['class'], axis = 1).values
y = normalized_df['class'].values.astype('int')

#initialisation PCA
pca = PCA(n_components = 61)
pca = pca.fit(x)
x_r = pca.transform(x)

print("# Of original features: ", x.shape[1])
print("# Features after reduction: ", x_r.shape[1])
# Out:
# # Of original features:  121
# # Features after reduction:  61

# %%
#Training splits
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size = 0.5, random_state = 42)

#reduced features splits
xr_train, xr_test, yr_train, yr_test = train_test_split(x_r, y, test_size = 0.3, random_state = 42)
xr_val, xr_test, yr_val, yr_test = train_test_split(xr_test, yr_test, test_size = 0.5, random_state = 42)

print("x_train shape : ", x_train.shape)
print("y_train shape : ", y_train.shape)

print("x_test shape : ", x_test.shape)
print("y_test shape : ", y_test.shape)
# Out:
# x_train shape :  (119350, 121)
# y_train shape :  (119350,)
# x_test shape :  (25575, 121)
# y_test shape :  (25575,)

# %% [markdown]
# #Models and evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix

evaluations = {}

def evaluate_model(model, X_test, y_true):
    # Step 2: Make predictions
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Step 3: Calculate accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Step 4: Calculate precision
    precision = precision_score(y_true, y_pred, average='weighted')

    # Step 5: Calculate F1-score
    f1score = f1_score(y_true, y_pred, average='weighted')

    # Step 6: Calculate confusion matrix
    confusion_mat = confusion_matrix(y_true, y_pred)

    # Print evaluation metrics
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("F1-score:", f1score)
    print("Confusion Matrix:")
    print(confusion_mat)

# %% [markdown]
# # Models

# %% [markdown]
# ### CNN

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

CNN = Sequential()
CNN.add(Conv1D(32, 3, activation='relu', input_shape=(121,1)))
CNN.add(Conv1D(64, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Flatten())
CNN.add(Dense(256, activation='relu'))
CNN.add(Dropout(0.5))
CNN.add(Dense(5, activation='softmax'))
CNN.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
CNN.summary()

# Train the CNN
history = CNN.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(CNN, x_test, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 119, 32)           128
#
#  conv1d_1 (Conv1D)           (None, 117, 64)           6208
#
#  max_pooling1d (MaxPooling1D  (None, 58, 64)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 56, 128)           24704
#
#  conv1d_3 (Conv1D)           (None, 54, 128)           49280
#
#  max_pooling1d_1 (MaxPooling  (None, 27, 128)          0
#  1D)
#
#  flatten (Flatten)           (None, 3456)              0
#
#  dense (Dense)               (None, 256)               884992
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 966,597
# Trainable params: 966,597
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1865/1865 [==============================] - 24s 6ms/step - loss: 1.2275 - accuracy: 0.9040 - val_loss: 0.2678 - val_accuracy: 0.9326
# Epoch 2/50
# 1865/1865 [==============================] - 11s 6ms/step - loss: 0
50
# 1865/1865 [==============================] - 11s 6ms/step - loss: 0.0594 - accuracy: 0.9798 - val_loss: 0.0979 - val_accuracy: 0.9753
# Epoch 45/50
# 1865/1865 [==============================] - 9s 5ms/step - loss: 0.1041 - accuracy: 0.9796 - val_loss: 0.1028 - val_accuracy: 0.9744
# Epoch 46/50
# 1865/1865 [==============================] - 11s 6ms/step - loss: 0.0591 - accuracy: 0.9802 - val_loss: 0.1071 - val_accuracy: 0.9741
# Epoch 47/50
# 1865/1865 [==============================] - 11s 6ms/step - loss: 0.1192 - accuracy: 0.9795 - val_loss: 0.0968 - val_accuracy: 0.9745
# Epoch 48/50
# 1865/1865 [==============================] - 11s 6ms/step - loss: 0.0636 - accuracy: 0.9804 - val_loss: 0.1026 - val_accuracy: 0.9752
# Epoch 49/50
# 1865/1865 [==============================] - 11s 6ms/step - loss: 0.0579 - accuracy: 0.9803 - val_loss: 0.1047 - val_accuracy: 0.9758
# Epoch 50/50
# 1865/1865 [==============================] - 10s 5ms/step - loss: 0.0572 - accuracy: 0.9805 - val_loss: 0.1035 - val_accuracy: 0.9749
# 800/800 [==============================] - 2s 2ms/step
# Accuracy: 0.9757184750733138
# Precision: 0.9760675860882271
# F1-score: 0.9758048763891708
# Confusion Matrix:
# [[11069    23    18   123     5]
#  [   98  7786    41    56     0]
#  [   28    70  1943    49     0]
#  [   65     7    25  1991    12]
#  [    1     0     0     0  2165]]

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM

cnn2 = Sequential()
cnn2.add(Conv1D(128, 3, activation='relu', input_shape=(121, 1)))
cnn2.add(MaxPooling1D(2))
cnn2.add(Conv1D(64, 3, activation='relu'))
cnn2.add(MaxPooling1D(2))
cnn2.add(Conv1D(64, 3, activation='relu'))
cnn2.add(MaxPooling1D(2))
cnn2.add(Flatten())
cnn2.add(Dense(128, activation='relu'))
cnn2.add(Dropout(0.5))
cnn2.add(Dense(64, activation='relu'))
cnn2.add(Dropout(0.5))
cnn2.add(Dense(5, activation='softmax'))

cnn2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn2.summary()
# Train the cnn2
history = cnn2.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(cnn2, x_test, y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 119, 128)          512
#
#  max_pooling1d_2 (MaxPooling  (None, 59, 128)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 57, 64)            24640
#
#  max_pooling1d_3 (MaxPooling  (None, 28, 64)           0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 26, 64)            12352
#
#  max_pooling1d_4 (MaxPooling  (None, 13, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 832)               0
#
#  dense_2 (Dense)             (None, 128)               106624
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 152,709
# Trainable params: 152,709
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 3730/3730 [==============================] - 23s 6ms/step - loss: 0.8430 - accuracy: 0.8405 - val_loss: 0.2434 - val_accuracy: 0.9169
# Epoch 2/20
# 3730/3730 [==============================] - 21s 6ms/step - loss: 0.3300 - accuracy: 0.9112 - val_loss: 0.1909 - val_accuracy: 0.9348
# Epoch 3/20
# 3730/3730 [==============================] - 21s 6ms/step - loss: 0.2392 - accuracy: 0.9293 - val_loss: 0.1598 - val_accuracy: 0.9458
# Epoch 4/20
# 3730/3730 [==============================] - 21s 6ms/step - loss: 2.0464 - accuracy: 0.9393 - val_loss: 0.1425 - val_accuracy: 0.9512
# Epoch 5/20
cnn_lstm.add(Conv1D(64, 3, activation='relu'))
cnn_lstm.add(MaxPooling1D(2))
cnn_lstm.add(Conv1D(128, 3, activation='relu'))
cnn_lstm.add(Conv1D(128, 3, activation='relu'))
cnn_lstm.add(MaxPooling1D(2))
cnn_lstm.add(LSTM(64, return_sequences=True))  
cnn_lstm.add(Dropout(0.5))
cnn_lstm.add(LSTM(32, return_sequences=False))
cnn_lstm.add(Dropout(0.1))
cnn_lstm.add(Dense(128, activation='relu'))
cnn_lstm.add(Dropout(0.3))
cnn_lstm.add(Dense(32, activation='relu'))
cnn_lstm.add(Dropout(0.2))
cnn_lstm.add(Dense(5, activation='softmax'))

cnn_lstm = cnn_lstm
cnn_lstm.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_lstm.summary()

# Train the cnn_lstm
history = cnn_lstm.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(cnn_lstm, x_test, y_test)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (None, 119, 32)           128
#
#  conv1d_12 (Conv1D)          (None, 117, 64)           6208
#
#  max_pooling1d_7 (MaxPooling  (None, 58, 64)           0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 56, 128)           24704
#
#  conv1d_14 (Conv1D)          (None, 54, 128)           49280
#
#  max_pooling1d_8 (MaxPooling  (None, 27, 128)          0
#  1D)
#
#  lstm_2 (LSTM)               (None, 27, 64)            49408
#
#  dropout_7 (Dropout)         (None, 27, 64)            0
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 128)               4224
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 32)                4128
#
#  dropout_10 (Dropout)        (None, 32)                0
#
#  dense_10 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 150,661
# Trainable params: 150,661
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1865/1865 [==============================] - 27s 11ms/step - loss: 0.4814 - accuracy: 0.8397 - val_loss: 0.2304 - val_accuracy: 0.9220
# Epoch 2/50
# 1865/1865 [==============================] - 21s 11ms/step - loss: 0.2402 - accuracy: 0.9200 - val_loss: 0.1971 - val_accuracy: 0.9305
# Epoch 3/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.2056 - accuracy: 0.9321 - val_loss: 0.1738 - val_accuracy: 0.9451
# Epoch 4/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.1760 - accuracy: 0.9437 - val_loss: 0.2036 - val_accuracy: 0.9337
# Epoch 5/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.1576 - accuracy: 0.9495 - val_loss: 0.1244 - val_accuracy: 0.9589
# Epoch 6/50
# 1865/1865 [==============================] - 26s 14ms/step - loss: 0.1438 - accuracy: 0.9544 - val_loss: 0.1223 - val_accuracy: 0.9607
# Epoch 7/50
# 1865/1865 [==============================] - 32s 17ms/step - loss: 0.1360 - accuracy: 0.9576 - val_loss: 0.1216 - val_accuracy: 0.9604
# Epoch 8/50
# 1865/1865 [==============================] - 27s 14ms/step - loss: 0.1263 - accuracy: 0.9608 - val_loss: 0.1093 - val_accuracy: 0.9645
# Epoch 9/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0
50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0861 - accuracy: 0.9725 - val_loss: 0.0922 - val_accuracy: 0.9708
# Epoch 34/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0883 - accuracy: 0.9716 - val_loss: 0.0947 - val_accuracy: 0.9707
# Epoch 35/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0846 - accuracy: 0.9729 - val_loss: 0.0907 - val_accuracy: 0.9713
# Epoch 36/50
# 1865/1865 [==============================] - 21s 11ms/step - loss: 0.0848 - accuracy: 0.9729 - val_loss: 0.0946 - val_accuracy: 0.9709
# Epoch 37/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0838 - accuracy: 0.9731 - val_loss: 0.0891 - val_accuracy: 0.9720
# Epoch 38/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0858 - accuracy: 0.9724 - val_loss: 0.0928 - val_accuracy: 0.9706
# Epoch 39/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0844 - accuracy: 0.9727 - val_loss: 0.0862 - val_accuracy: 0.9719
# Epoch 40/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0834 - accuracy: 0.9731 - val_loss: 0.0881 - val_accuracy: 0.9722
# Epoch 41/50
# 1865/1865 [==============================] - 21s 11ms/step - loss: 0.0842 - accuracy: 0.9728 - val_loss: 0.0888 - val_accuracy: 0.9719
# Epoch 42/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0832 - accuracy: 0.9731 - val_loss: 0.0893 - val_accuracy: 0.9716
# Epoch 43/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0822 - accuracy: 0.9727 - val_loss: 0.0886 - val_accuracy: 0.9722
# Epoch 44/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0829 - accuracy: 0.9733 - val_loss: 0.0855 - val_accuracy: 0.9728
# Epoch 45/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0809 - accuracy: 0.9736 - val_loss: 0.0880 - val_accuracy: 0.9726
# Epoch 46/50
# 1865/1865 [==============================] - 21s 11ms/step - loss: 0.0842 - accuracy: 0.9734 - val_loss: 0.0901 - val_accuracy: 0.9715
# Epoch 47/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0811 - accuracy: 0.9737 - val_loss: 0.0918 - val_accuracy: 0.9714
# Epoch 48/50
# 1865/1865 [==============================] - 20s 11ms/step - loss: 0.0807 - accuracy: 0.9739 - val_loss: 0.0907 - val_accuracy: 0.9719
# Epoch 49/50
# 1865/1865 [==============================] - 19s 10ms/step - loss: 0.0807 - accuracy: 0.9738 - val_loss: 0.0895 - val_accuracy: 0.9717
# Epoch 50/50
# 1865/1865 [==============================] - 21s 11ms/step - loss: 0.0798 - accuracy: 0.9744 - val_loss: 0.0876 - val_accuracy: 0.9716
# 800/800 [==============================] - 3s 3ms/step
# Accuracy: 0.9715347018572825
# Precision: 0.9723377292317182
# F1-score: 0.9717689327097704
# Confusion Matrix:
# [[11008    26    28   171     5]
#  [  113  7768    45    55     0]
#  [   28    67  1937    57     1]
#  [   55     4    30  1987    24]
#  [    0     0     0    19  2147]]

# %%
lstm = Sequential()
lstm.add(LSTM(128, return_sequences=True, input_shape=(121,1)))
lstm.add(LSTM(64, return_sequences=True))
lstm.add(LSTM(64))
lstm.add(Dense(128, activation='relu'))
lstm.add(Dropout(0.5))
lstm.add(Dense(5, activation='softmax'))
    
lstm.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
lstm.summary()

# Train the cnn_lstm
history = lstm.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(lstm, x_test, y_test)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 121, 128)          66560
#
#  lstm_5 (LSTM)               (None, 121, 64)           49408
#
#  lstm_6 (LSTM)               (None, 64)                33024
#
#  dense_11 (Dense)            (None, 128)               8320
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_12 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 157,957
# Trainable params: 157,957
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1865/1865 [==============================] - 47s 22ms/step - loss: 0.5861 - accuracy: 0.7864 - val_loss: 0.3683 - val_accuracy: 0.8615
# Epoch 2/50
# 1865/1865 [==============================] - 38s 20ms/step - loss: 0.3774 - accuracy: 0.8678 - val_loss: 0.3193 - val_accuracy: 0.8732
# Epoch 3/50
# 1865/1865 [==============================] - 36s 19ms/step - loss: 0.3369 - accuracy: 0.8781 - val_loss: 0.2942 - val_accuracy: 0.8908
# Epoch 4/50
# 1865/1865 [==============================] - 36s 19ms/step - loss: 0.2993 - accuracy: 0.8907 - val_loss: 0.2639 - val_accuracy: 0.9006
# Epoch 5/50
# 1865/1865 [==============================] - 34s 18ms/step - loss: 0.2803 - accuracy: 0.8960 - val_loss: 0.2399 - val_accuracy: 0.9078
# Epoch 6/50
# 1865/1865 [==============================] - 32s 17ms/step - loss: 0.2540 - accuracy: 0.9093 - val_loss: 0.2370 - val_accuracy: 0.9212
# Epoch 7/50
# 1865/1865 [==============================] - 32s 17ms/step - loss: 0.2307 - accuracy: 0.9210 - val_loss: 0.2089 - val_accuracy: 0.9295
# Epoch 8/50
# 1865/1865 [==============================] - 31s 17ms/step - loss: 0.2138 - accuracy: 0.9288 - val_loss: 0.1941 - val_accuracy: 0.9364
# Epoch 9/50
# 1865/1865 [==============================] - 34s 18ms/step - loss: 0.1945 - accuracy: 0.9359 - val_loss: 0.1999 - val_accuracy: 0.9344
# Epoch 10/50
# 1865/1865 [==============================] - 34s 18ms/step - loss: 0.1843 - accuracy: 0.9410 - val_loss: 0.1625 - val_accuracy: 0.9467
# Epoch 11/50
# 1865/1865 [==============================] - 34s 18ms/step - loss: 0.1744 - accuracy: 0.9445 - val_loss: 0.1720 - val_accuracy: 0.9443
# Epoch 12/50
# 1865/1865 [==============================] - 34s 18ms/step - loss: 0.1701 - accuracy: 0.9451 - val_loss: 0.1600 - val_accuracy: 0.9456
# Epoch 13/50
# 1865/1865 [==============================] - 31s 17ms/step - loss: 0.1627 - accuracy: 0.9484 - val_loss: 0.1366 - val_accuracy: 0.9555
# Epoch 14/50
# 1865/1865 [==============================] - 33s 17ms/step - loss: 0.1577 - accuracy: 0.9496 - val_loss: 0.1535 - val_accuracy: 0.9492
# Epoch 15/50
# 1865/1865 [==============================] - 31s 17ms/step - loss: 0.1637 - accuracy: 0.9473 - val_loss: 0.1539 - val_accuracy: 0.9478
