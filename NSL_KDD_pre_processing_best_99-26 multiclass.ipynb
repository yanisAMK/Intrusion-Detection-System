# %% [markdown]
# NSL-KDD Multi-class 5
# ---
#
# Accuracy: 0.9925193905271861
#
# Precision: 0.9925327544029282
#
# F1-score: 0.9925215669204571

# %% [markdown]
# #Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #Data

# %%
features = ['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot',
            'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations',
            'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate',
            'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count',
            'dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate',
            'dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate',
            'dst_host_srv_rerror_rate','class','difficulty_level']

# %%
from google.colab import drive
drive.mount('/content/drive')
train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/KDDTrain+.txt", names = features)
test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/KDDTest+.txt", names = features)

print(train_df.shape)
print(test_df.shape)
# Out:
# Mounted at /content/drive
# (125967, 43)
# (22549, 43)

# %%
#combining train and test files (there's an error when doing the one hot encoding)
data = pd.concat([train_df, test_df])
print(data.shape)
data.head()
# Out:
# (148516, 43)
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#      class  difficulty_level
# 0   normal                20
# 1   normal                15
# 2  neptune                19
# 3   normal                21
# 4   normal                21
#
# [5 rows x 43 columns]

# %%
data.info()

""" 
  'protocol_type','srevice', 'flag' : categorical types
  'difficulty_level'                : usless
  'class'                           : has multiplie classes of attaks and a normal class
  
  'is_host_login','land', 'logged_in','is_guest_login' : binary no need for normalizing
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148516 entries, 0 to 22548
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148516 non-null  int64
#  1   protocol_type                148516 non-null  object
#  2   service                      148516 non-null  object
#  3   flag                         148516 non-null  object
#  4   src_bytes                    148516 non-null  int64
#  5   dst_bytes                    148516 non-null  int64
#  6   land                         148516 non-null  int64
#  7   wrong_fragment               148516 non-null  int64
#  8   urgent                       148516 non-null  int64
#  9   hot                          148516 non-null  int64
#  10  num_failed_logins            148516 non-null  int64
#  11  logged_in                    148516 non-null  int64
#  12  num_compromised              148516 non-null  int64
#  13  root_shell                   148516 non-null  int64
#  14  su_attempted                 148516 non-null  int64
#  15  num_root                     148516 non-null  int64
#  16  num_file_creations           148516 non-null  int64
#  17  num_shells                   148516 non-null  int64
#  18  num_access_files             148516 non-null  int64
#  19  num_outbound_cmds            148516 non-null  int64
#  20  is_host_login                148516 non-null  int64
#  21  is_guest_login               148516 non-null  int64
#  22  count                        148516 non-null  int64
#  23  srv_count                    148516 non-null  int64
#  24  serror_rate                  148516 non-null  float64
#  25  srv_serror_rate              148516 non-null  float64
#  26  rerror_rate                  148516 non-null  float64
#  27  srv_rerror_rate              148516 non-null  float64
#  28  same_srv_rate                148516 non-null  float64
#  29  diff_srv_rate                148516 non-null  float64
#  30  srv_diff_host_rate           148516 non-null  float64
#  31  dst_host_count               148516 non-null  int64
#  32  dst_host_srv_count           148516 non-null  int64
#  33  dst_host_same_srv_rate       148516 non-null  float64
#  34  dst_host_diff_srv_rate       148516 non-null  float64
#  35  dst_host_same_src_port_rate  148516 non-null  float64
#  36  dst_host_srv_diff_host_rate  148516 non-null  float64
#  37  dst_host_serror_rate         148516 non-null  float64
#  38  dst_host_srv_serror_rate     148516 non-null  float64
#  39  dst_host_rerror_rate         148516 non-null  float64
#  40  dst_host_srv_rerror_rate     148516 non-null  float64
#  41  class                        148516 non-null  object
#  42  difficulty_level             148516 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 49.9+ MB
# " \n  'protocol_type','srevice', 'flag' : categorical types\n  'difficulty_level'                : usless\n  'class'                           : has multiplie classes of attaks and a normal class\n  \n  'is_host_login','land', 'logged_in','is_guest_login' : binary no need for normalizing\n"

# %%
#some stats
data.describe().style.background_gradient(cmap='Blues').set_properties(**{'font-family':'Segoe UI'})
# Out:
# <style type="text/css">
# #T_ebe0b_row0_col0, #T_ebe0b_row0_col3, #T_ebe0b_row0_col4, #T_ebe0b_row0_col5, #T_ebe0b_row0_col6, #T_ebe0b_row0_col7, #T_ebe0b_row0_col8, #T_ebe0b_row0_col9, #T_ebe0b_row0_col10, #T_ebe0b_row0_col11, #T_ebe0b_row0_col12, #T_ebe0b_row0_col13, #T_ebe0b_row0_col14, #T_ebe0b_row0_col15, #T_ebe0b_row0_col16, #T_ebe0b_row0_col17, #T_ebe0b_row0_col18, #T_ebe0b_row0_col19, #T_ebe0b_row0_col20, #T_ebe0b_row0_col21, #T_ebe0b_row0_col22, #T_ebe0b_row0_col23, #T_ebe0b_row0_col24, #T_ebe0b_row0_col25, #T_ebe0b_row0_col26, #T_ebe0b_row0_col27, #T_ebe0b_row0_col28, #T_ebe0b_row0_col29, #T_ebe0b_row0_col30, #T_ebe0b_row0_col31, #T_ebe0b_row0_col32, #T_ebe0b_row0_col33, #T_ebe0b_row0_col34, #T_ebe0b_row0_col35, #T_ebe0b_row0_col36, #T_ebe0b_row0_col37, #T_ebe0b_row0_col38, #T_ebe0b_row7_col1, #T_ebe0b_row7_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_ebe0b_row0_col1, #T_ebe0b_row0_col2, #T_ebe0b_row1_col0, #T_ebe0b_row1_col1, #T_ebe0b_row1_col2, #T_ebe0b_row1_col3, #T_ebe0b_row1_col4, #T_ebe0b_row1_col5, #T_ebe0b_row1_col6, #T_ebe0b_row1_col7, #T_ebe0b_row1_col8, #T_ebe0b_row1_col9, #T_ebe0b_row1_col10, #T_ebe0b_row1_col11, #T_ebe0b_row1_col12, #T_ebe0b_row1_col13, #T_ebe0b_row1_col14, #T_ebe0b_row1_col15, #T_ebe0b_row1_col16, #T_ebe0b_row1_col17, #T_ebe0b_row1_col18, #T_ebe0b_row1_col19, #T_ebe0b_row1_col20, #T_ebe0b_row1_col21, #T_ebe0b_row1_col22, #T_ebe0b_row1_col23, #T_ebe0b_row1_col24, #T_ebe0b_row1_col25, #T_ebe0b_row1_col26, #T_ebe0b_row1_col27, #T_ebe0b_row1_col28, #T_ebe0b_row1_col29, #T_ebe0b_row1_col30, #T_ebe0b_row1_col31, #T_ebe0b_row1_col32, #T_ebe0b_row1_col33, #T_ebe0b_row1_col34, #T_ebe0b_row1_col35, #T_ebe0b_row1_col36, #T_ebe0b_row1_col37, #T_ebe0b_row1_col38, #T_ebe0b_row2_col2, #T_ebe0b_row2_col3, #T_ebe0b_row2_col4, #T_ebe0b_row2_col5, #T_ebe0b_row2_col6, #T_ebe0b_row2_col7, #T_ebe0b_row2_col8, #T_ebe0b_row2_col9, #T_ebe0b_row2_col10, #T_ebe0b_row2_col11, #T_ebe0b_row2_col12, #T_ebe0b_row2_col13, #T_ebe0b_row2_col14, #T_ebe0b_row2_col15, #T_ebe0b_row2_col16, #T_ebe0b_row2_col17, #T_ebe0b_row2_col18, #T_ebe0b_row2_col19, #T_ebe0b_row2_col20, #T_ebe0b_row2_col21, #T_ebe0b_row2_col22, #T_ebe0b_row2_col23, #T_ebe0b_row2_col24, #T_ebe0b_row2_col25, #T_ebe0b_row2_col26, #T_ebe0b_row2_col27, #T_ebe0b_row2_col28, #T_ebe0b_row2_col29, #T_ebe0b_row2_col30, #T_ebe0b_row2_col31, #T_ebe0b_row2_col32, #T_ebe0b_row2_col33, #T_ebe0b_row2_col34, #T_ebe0b_row2_col35, #T_ebe0b_row2_col36, #T_ebe0b_row2_col37, #T_ebe0b_row2_col38, #T_ebe0b_row3_col0, #T_ebe0b_row3_col1, #T_ebe0b_row3_col2, #T_ebe0b_row3_col3, #T_ebe0b_row3_col4, #T_ebe0b_row3_col5, #T_ebe0b_row3_col6, #T_ebe0b_row3_col7, #T_ebe0b_row3_col8, #T_ebe0b_row3_col9, #T_ebe0b_row3_col10, #T_ebe0b_row3_col11, #T_ebe0b_row3_col12, #T_ebe0b_row3_col13, #T_ebe0b_row3_col14, #T_ebe0b_row3_col15, #T_ebe0b_row3_col16, #T_ebe0b_row3_col17, #T_ebe0b_row3_col18, #T_ebe0b_row3_col19, #T_ebe0b_row3_col20, #T_ebe0b_row3_col21, #T_ebe0b_row3_col22, #T_ebe0b_row3_col23, #T_ebe0b_row3_col24, #T_ebe0b_row3_col25, #T_ebe0b_row3_col26, #T_ebe0b_row3_col27, #T_ebe0b_row3_col28, #T_ebe0b_row3_col29, #T_ebe0b_row3_col30, #T_ebe0b_row3_col31, #T_ebe0b_row3_col32, #T_ebe0b_row3_col33, #T_ebe0b_row3_col34, #T_ebe0b_row3_col35, #T_ebe0b_row3_col36, #T_ebe0b_row3_col37, #T_ebe0b_row3_col38, #T_ebe0b_row4_col0, #T_ebe0b_row4_col1, #T_ebe0b_row4_col2, #T_ebe0b_row4_col3, #T_ebe0b_row4_col4, #T_ebe0b_row4_col5, #T_ebe0b_row4_col6, #T_ebe0b_row4_col7, #T_ebe0b_row4_col8, #T_ebe0b_row4_col9, #T_ebe0b_row4_col10, #T_ebe0b_row4_col11, #T_ebe0b_row4_col12, #T_ebe0b_row4_col13, #T_ebe0b_row4_col14, #T_ebe0b_row4_col15, #T_ebe0b_row4_col16, #T_ebe0b_row4_col17, #T_ebe0b_row4_col18, #T_ebe0b_row4_col19, #T_ebe0b_row4_col20, #T_ebe0b_row4_col21, #T_ebe0b_row4_col22, #T_ebe0b_row4_col23, #T_ebe0b_row4_col24, #T_ebe0b_row4_col25, #T_ebe0b_row4_col26, #T_ebe0b_row4_col27, #T_ebe0b_row4_col28, #T_ebe0b_row4_col29, #T_ebe0b_row4_col30, #T_ebe0b_row4_col31, #T_ebe0b_row4_col32, #T_ebe0b_row4_col33, #T_ebe0b_row4_col34, #T_ebe0b_row4_col35, #T_ebe0b_row4_col36, #T_ebe0b_row4_col37, #T_ebe0b_row4_col38, #T_ebe0b_row5_col0, #T_ebe0b_row5_col1, #T_ebe0b_row5_col2, #T_ebe0b_row5_col3, #T_ebe0b_row5_col4, #T_ebe0b_row5_col5, #T_ebe0b_row5_col6, #T_ebe0b_row5_col7, #T_ebe0b_row5_col8, #T_ebe0b_row5_col9, #T_ebe0b_row5_col10, #T_ebe0b_row5_col11, #T_ebe0b_row5_col12, #T_ebe0b_row5_col13, #T_ebe0b_row5_col14, #T_ebe0b_row5_col15, #T_ebe0b_row5_col16, #T_ebe0b_row5_col17, #T_ebe0b_row5_col18, #T_ebe0b_row5_col19, #T_ebe0b_row5_col20, #T_ebe0b_row5_col21, #T_ebe0b_row5_col22, #T_ebe0b_row5_col23, #T_ebe0b_row5_col24, #T_ebe0b_row5_col25, #T_ebe0b_row5_col26, #T_ebe0b_row5_col27, #T_ebe0b_row5_col28, #T_ebe0b_row5_col29, #T_ebe0b_row5_col30, #T_ebe0b_row5_col31, #T_ebe0b_row5_col32, #T_ebe0b_row5_col33, #T_ebe0b_row5_col34, #T_ebe0b_row5_col35, #T_ebe0b_row5_col3 ...
#   background-color: #f7fbff;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_ebe0b_row2_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_ebe0b_row2_col1 {
#   background-color: #f6faff;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_ebe0b_row7_col0 {
#   background-color: #99c7e0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_ebe0b_row7_col9, #T_ebe0b_row7_col12 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_ebe0b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebe0b_level0_col0" class="col_heading level0 col0" >duration</th>
#       <th id="T_ebe0b_level0_col1" class="col_heading level0 col1" >src_bytes</th>
#       <th id="T_ebe0b_level0_col2" class="col_heading level0 col2" >dst_bytes</th>
#       <th id="T_ebe0b_level0_col3" class="col_heading level0 col3" >land</th>
#       <th id="T_ebe0b_level0_col4" class="col_heading level0 col4" >wrong_fragment</th>
#       <th id="T_ebe0b_level0_col5" class="col_heading level0 col5" >urgent</th>
#       <th id="T_ebe0b_level0_col6" class="col_heading level0 col6" >hot</th>
#       <th id="T_ebe0b_level0_col7" class="col_heading level0 col7" >num_failed_logins</th>
#       <th id="T_ebe0b_level0_col8" class="col_heading level0 col8" >logged_in</th>
#       <th id="T_ebe0b_level0_col9" class="col_heading level0 col9" >num_compromised</th>
#       <th id="T_ebe0b_level0_col10" class="col_heading level0 col10" >root_shell</th>
#       <th id="T_ebe0b_l

# %% [markdown]
# ### fixing labels

# %%
#Actual labels
print(data['class'].value_counts())
# Out:
# normal             77054
# neptune            45871
# satan               4367
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: class, dtype: int64

# %%
#fixing labels

dos_class =["apache2","back","land","neptune","mailbomb","pod","processtable","smurf","teardrop","udpstorm","worm"]
R2L_class =["ftp_write","guess_passwd","imap","multihop","named","phf","sendmail","snmpgetattack","spy","snmpguess","warezclient","warezmaster","xlock","xsnoop"]      
Probe_class =["ipsweep","mscan","nmap","portsweep","saint","satan"]
U2R_class =["buffer_overflow","loadmodule","perl","ps","rootkit","sqlattack","xterm","httptunnel"]

for atk in dos_class:
  data.loc[data['class'] == atk, 'class'] = 'DoS'
for atk in R2L_class: 
  data.loc[data['class'] == atk, 'class'] = 'R2L'
for atk in Probe_class: 
  data.loc[data['class'] == atk, 'class'] = 'Probe'
for atk in U2R_class :
  data.loc[data['class'] == atk, 'class'] = "U2R"

data['class'].value_counts()
# Out:
# normal    77054
# DoS       53387
# Probe     14076
# R2L        3747
# U2R         252
# Name: class, dtype: int64

# %% [markdown]
# ##Data visualisation

# %% [markdown]
# ###Repartition des classes

# %%
data['class'].value_counts().plot(kind = "pie" ,figsize=(5, 5), fontsize=10, autopct='%1.0f%%')
# Out:
# <Axes: ylabel='class'>

# %%
#data.plot(kind='box',subplots=True,layout=(6,8),figsize=(20,40))
plt.show()

# %% [markdown]
# # prétraitement

# %%
data
# Out:
#        duration protocol_type    service flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   ftp_data   SF        491          0     0
# 1             0           udp      other   SF        146          0     0
# 2             0           tcp    private   S0          0          0     0
# 3             0           tcp       http   SF        232       8153     0
# 4             0           tcp       http   SF        199        420     0
# ...         ...           ...        ...  ...        ...        ...   ...
# 22544         0          icmp      red_i   SF         91          0     0
# 22545         0          icmp      urh_i   SF         36          0     0
# 22546         0           tcp  http_8001   S0          0          0     0
# 22547         0           tcp        aol  REJ          0          0     0
# 22548         0           tcp    harvest   S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.17
# 1                   0       0    0  ...                    0.00
# 2                   0       0    0  ...                    0.10
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    1.00
# ...               ...     ...  ...  ...                     ...
# 22544               0       0    0  ...                    0.01
# 22545               0       0    0  ...                    0.14
# 22546               0       0    0  ...                    0.00
# 22547               0       0    0  ...                    0.00
# 22548               0       0    0  ...                    0.00
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                        0.03                         0.17
# 1                        0.60                         0.88
# 2                        0.05                         0.00
# 3                        0.00                         0.03
# 4                        0.00                         0.00
# ...                       ...                          ...
# 22544                    0.02                         0.01
# 22545                    0.07                         0.14
# 22546                    1.00                         0.00
# 22547                    1.00                         0.00
# 22548                    1.00                         0.00
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.00                  1.00
# 3                             0.04                  0.03
# 4                             0.00                  0.00
# ...                            ...                   ...
# 22544                         0.00                  0.00
# 22545                         0.00                  0.00
# 22546                         0.00                  0.13
# 22547                         0.00                  0.03
# 22548                         0.00                  0.17
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                          0.00                  0.05
# 1                          0.00                  0.00
# 2                          1.00                  0.00
# 3                          0.01                  0.00
# 4                          0.00                  0.00
# ...                         ...                   ...
# 22544                      0.00                  0.11
# 22545                      0.00                  0.00
# 22546                      1.00                  0.87
# 22547                      0.00                  0.97
# 22548                      1.00                  0.82
#
#        dst_host_srv_rerror_rate   class  difficulty_level
# 0                          0.00  normal                20
# 1                          0.00  normal                15
# 2                          0.00     DoS                19
# 3                          0.01  normal                21
# 4                          0.00  normal                21
# ...                         ...     ...               ...
# 22544                      0.00  normal                20
# 22545                      0.00  normal                21
# 22546                      0.00   Probe                17
# 22547                      1.00   Probe                17
# 22548                      0.00   Probe                17
#
# [148516 rows x 43 columns]

# %% [markdown]
# ##### 1-Normalisation (Robuste)

# %%
#les colonnes doivent etre numeriques seulement
def normalisation(dataframe, columns):
  normalised_df = pd.DataFrame(RobustScaler().fit_transform(dataframe), columns = columns)
  return normalised_df

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
def standardization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
categorical_columns = ['is_host_login','protocol_type','service','flag','land', 'logged_in','is_guest_login', 'difficulty_level', 'class']

# %%
def preprocessing(dataframe):
  #selectionner le valeurs numeriques puis les normaliser
  num_df = dataframe.drop(categorical_columns, axis=1)
  num_cols = num_df.columns
  #normalized_df = normalisation(num_df, num_cols) #RobustScaler
  normalized_df = standardization(num_df, num_cols) #standardScaler

  #supression des ancienne données numeriques et rajout des données normalisées
  dataframe.drop(labels = num_cols, axis= 'columns', inplace = True)
  dataframe[num_cols] = normalized_df[num_cols]
  
  
  #remplaces les lables de la colonne 'class": 
  #0 => normal
  #1 => Dos
  #2 => Probe
  #3 => R2L
  #4 => U2R
  dataframe.loc[dataframe['class'] == "normal", "class"]= 0
  dataframe.loc[dataframe['class'] == "DoS", "class"]= 1
  dataframe.loc[dataframe['class'] == "Probe", "class"]= 2
  dataframe.loc[dataframe['class'] == "R2L", "class"]= 3
  dataframe.loc[dataframe['class'] == "U2R", "class"]= 4 

  #onehot encoding
  dataframe = pd.get_dummies(dataframe, columns = ['protocol_type','service', 'flag'])

  return dataframe

# %%
normalized_df = preprocessing(data)

# %% [markdown]
# #####Data augmentation

# %%
#code to augment some classes
normalized_df['class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
minority_classes = [ 2 , 3 , 4]
mask = normalized_df['class'].isin(minority_classes)
minority_df = normalized_df[mask]
minority_df
# Out:
#        land  logged_in  is_host_login  is_guest_login class  difficulty_level  \
# 13        0          1              0               0     3                15
# 17        0          0              0               0     2                18
# 30        0          0              0               0     2                17
# 33        0          0              0               0     2                20
# 48        0          1              0               0     3                12
# ...     ...        ...            ...             ...   ...               ...
# 22524     0          1              0               0     4                 4
# 22543     0          0              0               0     2                14
# 22546     0          0              0               0     2                17
# 22547     0          0              0               0     2                17
# 22548     0          0              0               0     2                17
#
#        duration  src_bytes  dst_bytes  wrong_fragment  ...  flag_REJ  \
# 13    -0.112481  -0.007375  -0.004614       -0.085488  ...         0
# 17    -0.112481  -0.007433  -0.004614       -0.085488  ...         0
# 30    -0.112481  -0.007435  -0.004614       -0.085488  ...         0
# 33    -0.112481  -0.007436  -0.004614       -0.085488  ...         1
# 48    -0.112481  -0.007375  -0.004614       -0.085488  ...         0
# ...         ...        ...        ...             ...  ...       ...
# 22524 -0.106386  -0.007428  -0.004556       -0.085488  ...         0
# 22543 -0.112481  -0.007436  -0.004614       -0.085488  ...         1
# 22546 -0.112481  -0.007436  -0.004614       -0.085488  ...         0
# 22547 -0.112481  -0.007436  -0.004614       -0.085488  ...         1
# 22548 -0.112481  -0.007436  -0.004614       -0.085488  ...         0
#
#        flag_RSTO  flag_RSTOS0  flag_RSTR  flag_S0  flag_S1  flag_S2  flag_S3  \
# 13             0            0          0        0        0        0        0
# 17             0            0          0        0        0        0        0
# 30             0            0          0        0        0        0        0
# 33             0            0          0        0        0        0        0
# 48             0            0          0        0        0        0        0
# ...          ...          ...        ...      ...      ...      ...      ...
# 22524          0            0          0        0        0        0        0
# 22543          0            0          0        0        0        0        0
# 22546          0            0          0        1        0        0        0
# 22547          0            0          0        0        0        0        0
# 22548          0            0          0        1        0        0        0
#
#        flag_SF  flag_SH
# 13           1        0
# 17           1        0
# 30           1        0
# 33           0        0
# 48           1        0
# ...        ...      ...
# 22524        1        0
# 22543        0        0
# 22546        0        0
# 22547        0        0
# 22548        0        0
#
# [18075 rows x 123 columns]

# %%
#code--
from imblearn.over_sampling import SMOTE

minority = minority_df.drop(['difficulty_level'], axis = 1)
xm = minority.drop(['class'], axis = 1)
ym = minority['class']

smote = SMOTE()
augmented_x, augmented_y = smote.fit_resample(xm.values,ym.values.astype('int'))

# %%
original_df = normalized_df
xmc = pd.DataFrame(xm).columns
ymc = pd.DataFrame(ym).columns
augmented = pd.concat([pd.DataFrame(augmented_x, columns=xmc), pd.DataFrame(augmented_y, columns = ymc)], axis = 1)
normalized_df = pd.concat([pd.DataFrame(normalized_df.drop(['difficulty_level'], axis = 1)), augmented])
normalized_df['class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ##### Data analysing

# %%
print("Data Cleaning process: \n")
# instances dupliquées 
print("number of duplicated instances :",normalized_df.duplicated().sum())
#suppression 
normalized_df = normalized_df.drop_duplicates()

print("\n")
# verifier les valeurs manquantes
missing_values = normalized_df.isnull().any(axis=1)

if missing_values.any():
    print("There are instances with missing values:")
    print(normalized_df[missing_values])
else:
    print("There are no instances with missing values.")

# colones ayant la meme valuers
unique_counts = normalized_df.nunique()
columns = unique_counts[unique_counts == 1].index.tolist()
print("\ncolones avec les memes valeurs: ",columns)
print("\n")
# paires d'attributs ayant une correlation elvée
# Calculate the correlation matrix
corr_matrix = normalized_df.corr()

# Find unique attribute pairs with correlation above 0.90
high_corr_pairs = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > 0.90:
            pair = (corr_matrix.columns[i], corr_matrix.columns[j])
            high_corr_pairs.add(tuple(sorted(pair)))

# Print the unique attribute pairs with high correlation
count = 0
for pair in high_corr_pairs:
    count +=1
    print(f"Attributes '{pair[0]}' and '{pair[1]}' have correlation above 0.90.")
print (count)
# Out:
# Data Cleaning process:
#
# number of duplicated instances : 18740
#
#
# There are no instances with missing values.
#
# colones avec les memes valeurs:  ['num_outbound_cmds']
# <ipython-input-21-031bb403cfef>:24: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = normalized_df.corr()
# Attributes 'flag_S0' and 'srv_serror_rate' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'serror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_rerror_rate' and 'srv_rerror_rate' have correlation above 0.90.
# Attributes 'serror_rate' and 'srv_serror_rate' have correlation above 0.90.
# Attributes 'rerror_rate' and 'srv_rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'flag_S0' have correlation above 0.90.
# Attributes 'dst_host_srv_serror_rate' and 'serror_rate' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'srv_serror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_rerror_rate' and 'rerror_rate' have correlation above 0.90.
# Attributes 'flag_S0' and 'serror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_serror_rate' and 'flag_S0' have correlation above 0.90.
# Attributes 'num_compromised' and 'num_root' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'dst_host_srv_serror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_serror_rate' and 'srv_serror_rate' have correlation above 0.90.
# 14

# %% [markdown]
# ##### Data Cleaning

# %%
# List of columns to remove
columns_to_remove = ['serror_rate', 'num_compromised', 'flag_S0','dst_host_rerror_rate',
                     'dst_host_srv_rerror_rate', 'dst_host_serror_rate',
                     'rerror_rate', 'dst_host_srv_serror_rate', 'num_outbound_cmds']

# Remove the specified columns
normalized_df.drop(columns = columns_to_remove, axis=1, inplace=True)

# %%
pd.DataFrame(normalized_df)['class'].value_counts()
# Out:
# 0    76967
# 1    52987
# 4    14076
# 3    14040
# 2    13934
# Name: class, dtype: int64

# %%
normalized_df = normalized_df.sample(frac = 1, random_state = 42)
normalized_df = normalized_df.reset_index(drop = True)

# %% [markdown]
# ##### Feature selection (reduction) PCA

# %%
#Extraction des X et Y
x = normalized_df.drop(['class'], axis = 1).values
y = normalized_df['class'].values.astype('int')

#initialisation PCA
pca = PCA(n_components = 108)
pca = pca.fit(x)
x_r = pca.transform(x)

print("# Of original features: ", x.shape[1])
print("# Features after reduction: ", x_r.shape[1])
# Out:
# # Of original features:  112
# # Features after reduction:  108

# %%
#Training splits
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size = 0.5, random_state = 42)

#reduced features splits
xr_train, xr_test, yr_train, yr_test = train_test_split(x_r, y, test_size = 0.3, random_state = 42)
xr_val, xr_test, yr_val, yr_test = train_test_split(xr_test, yr_test, test_size = 0.5, random_state = 42)

print("x_train shape : ", x_train.shape)
print("y_train shape : ", y_train.shape)

print("x_test shape : ", x_test.shape)
print("y_test shape : ", y_test.shape)
# Out:
# x_train shape :  (120402, 112)
# y_train shape :  (120402,)
# x_test shape :  (25801, 112)
# y_test shape :  (25801,)

# %% [markdown]
# #Models and evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix, classification_report
import seaborn as sns

def evaluate_model(model, X_test, y_true):
    # Step 2: Make predictions
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Step 3: Calculate accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Step 4: Calculate precision
    precision = precision_score(y_true, y_pred, average='weighted')

    # Step 5: Calculate F1-score
    f1score = f1_score(y_true, y_pred, average='weighted')

    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("F1-score:", f1score)
    # Generate the classification report
    print("\n\n",classification_report(y_test, y_pred))

    # Step 6: Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)


    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(4, 3))

    # Plot the confusion matrix as a heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax)

    # Set labels and title
    classes = ['Normal', 'DoS', 'Probe', 'R2L', 'U2R']  
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix')

    # Set x-axis and y-axis tick labels
    ax.xaxis.set_ticklabels(classes)
    ax.yaxis.set_ticklabels(classes)

    # Rotate the tick labels for better visibility
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)

    # Display the plot
    plt.show()

# %% [markdown]
# # Models

# %% [markdown]
# ### CNN

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM

# %%
CNN = Sequential()
CNN.add(Conv1D(32, 3, activation='relu', input_shape=(112,1)))
CNN.add(Conv1D(64, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Dropout(0.2))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Dropout(0.2))
CNN.add(Flatten())
CNN.add(Dense(256, activation='relu'))
CNN.add(Dropout(0.5))
CNN.add(Dense(5, activation='softmax'))
CNN.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
CNN.summary()

# Train the CNN
history = CNN.fit(x_train, y_train, epochs=100, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(CNN, x_test, y_test)

# %%
path = "/content/drive/MyDrive/Colab Notebooks/h5 files/"

# %%
CNN.save(path +"Cnn precision_99 input_113 .h5")

# %%
cnn2 = Sequential()
cnn2.add(Dense(32, activation='relu', input_shape=(112,1)))
cnn2.add(Conv1D(64, 3, activation='relu'))
cnn2.add(Conv1D(64, 3, activation='relu'))
cnn2.add(MaxPooling1D(2))
cnn2.add(Dropout(0.2))
cnn2.add(Conv1D(128, 3, activation='relu'))
cnn2.add(Conv1D(128, 3, activation='relu'))
cnn2.add(MaxPooling1D(2))
cnn2.add(Dropout(0.2))
cnn2.add(Flatten())
cnn2.add(Dense(256, activation='relu'))
cnn2.add(Dropout(0.5))
cnn2.add(Dense(5, activation='softmax'))
cnn2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn2.summary()

# Train the cnn2
history = cnn2.fit(x_train, y_train, epochs=100, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(cnn2, x_test, y_test)

# %% [markdown]
# ### cnn lstm

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(112, 1)))
model.add(Conv1D(128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
#model.add(Dropout(0.4))
model.add(Dense(5, activation='softmax'))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Train the model
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(model, x_test, y_test)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 112, 128)          256
#
#  conv1d_1 (Conv1D)           (None, 110, 128)          49280
#
#  max_pooling1d_1 (MaxPooling  (None, 55, 128)          0
#  1D)
#
#  lstm_1 (LSTM)               (None, 55, 128)           131584
#
#  dropout_1 (Dropout)         (None, 55, 128)           0
#
#  flatten_1 (Flatten)         (None, 7040)              0
#
#  dense_4 (Dense)             (None, 64)                450624
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 632,069
# Trainable params: 632,069
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1882/1882 [==============================] - 23s 9ms/step - loss: 0.1288 - accuracy: 0.9543 - val_loss: 0.0809 - val_accuracy: 0.9693
# Epoch 2/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0670 - accuracy: 0.9753 - val_loss: 0.0539 - val_accuracy: 0.9797
# Epoch 3/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0545 - accuracy: 0.9796 - val_loss: 0.0447 - val_accuracy: 0.9834
# Epoch 4/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0463 - accuracy: 0.9828 - val_loss: 0.0409 - val_accuracy: 0.9853
# Epoch 5/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0421 - accuracy: 0.9847 - val_loss: 0.0417 - val_accuracy: 0.9841
# Epoch 6/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0390 - accuracy: 0.9851 - val_loss: 0.0413 - val_accuracy: 0.9852
# Epoch 7/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0362 - accuracy: 0.9866 - val_loss: 0.0375 - val_accuracy: 0.9869
# Epoch 8/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0338 - accuracy: 0.9872 - val_loss: 0.0399 - val_accuracy: 0.9852
# Epoch 9/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0322 - accuracy: 0.9881 - val_loss: 0.0345 - val_accuracy: 0.9869
# Epoch 10/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0306 - accuracy: 0.9887 - val_loss: 0.0344 - val_accuracy: 0.9868
# Epoch 11/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0298 - accuracy: 0.9890 - val_loss: 0.0289 - val_accuracy: 0.9897
# Epoch 12/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0286 - accuracy: 0.9893 - val_loss: 0.0304 - val_accuracy: 0.9885
# Epoch 13/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0277 - accuracy: 0.9895 - val_loss: 0.0289 - val_accuracy: 0.9896
# Epoch 14/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0272 - accuracy: 0.9898 - val_loss: 0.0272 - val_accuracy: 0.9899
# Epoch 15/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0259 - accuracy: 0.9901 - val_loss: 0.0284 - val_accuracy: 0.9895
# Epoch 16/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0255 - accuracy: 0.9902 - val_loss: 0.0331 - val_accuracy: 0.9886
# Epoch 17/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0250 - accuracy: 0.9904 - val_loss: 0.0288 - val_accuracy: 0.9898
# Epoch 18/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0244 - accuracy: 0.9907 - val_loss: 0.0292 - val_accuracy: 0.9890
# Epoch 19/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0240 - accuracy: 0.9910 - val_loss: 0.0297 - val_accuracy: 0.9899
# Epoch 20/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0228 - accuracy: 0.9915 - val_loss: 0.0296 - val_accuracy: 0.9894
# Epoch 21/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0231 - accuracy: 0.9913 - val_loss: 0.0250 - val_accuracy: 0.9903
# Epoch 22/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0226 - accuracy: 0.9915 - val_loss: 0.0270 - val_accuracy: 0.9894
# Epoch 23/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0216 - accuracy: 0.9917 - val_loss: 0.0288 - val_accuracy: 0.9889
# Epoch 24/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0212 - accuracy: 0.9921 - val_loss: 0.0298 - val_accuracy: 0.9899
# Epoch 25/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0214 - accuracy: 0.9918 - val_loss: 0.0252 - val_accuracy: 0.9920
# Epoch 26/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0208 - accuracy: 0.9920 - val_loss: 0.0253 - val_accuracy: 0.9907
# Epoch 27/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0205 - accuracy: 0.9923 - val_loss: 0.0293 - val_accuracy: 0.9904
# Epoch 28/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 0.0274 - val_accuracy: 0.9903
# Epoch 29/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0201 - accuracy: 0.9923 - val_loss: 0.0264 - val_accuracy: 0.9909
# Epoch 30/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0198 - accuracy: 0.9924 - val_loss: 0.0294 - val_accuracy: 0.9894
# Epoch 31/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0196 - accuracy: 0.9925 - val_loss: 0.0263 - val_accuracy: 0.9912
# Epoch 32/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.0266 - val_accuracy: 0.9916
# Epoch 33/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0196 - accuracy: 0.9925 - val_loss: 0.0303 - val_accuracy: 0.9896
# Epoch 34/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0187 - accuracy: 0.9928 - val_loss: 0.0243 - val_accuracy: 0.9917
# Epoch 35/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0190 - accuracy: 0.9929 - val_loss: 0.0270 - val_accuracy: 0.9917
# Epoch 36/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0187 - accuracy: 0.9928 - val_loss: 0.0275 - val_accuracy: 0.9912
# Epoch 37/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0187 - accuracy: 0.9930 - val_loss: 0.0288 - val_accuracy: 0.9916
# Epoch 38/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0181 - accuracy: 0.9930 - val_loss: 0.0281 - val_accuracy: 0.9913
# Epoch 39/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0182 - accuracy: 0.9931 - val_loss: 0.0275 - val_accuracy: 0.9915
# Epoch 40/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0181 - accuracy: 0.9933 - val_loss: 0.0303 - val_accuracy: 0.9905
# Epoch 41/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0184 - accuracy: 0.9930 - val_loss: 0.0286 - val_accuracy: 0.9910
# Epoch 42/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0171 - accuracy: 0.9933 - val_loss: 0.0258 - val_accuracy: 0.9911
# Epoch 43/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0180 - accuracy: 0.9931 - val_loss: 0.0252 - val_accuracy: 0.9920
# Epoch 44/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0178 - accuracy: 0.9935 - val_loss: 0.0257 - val_accuracy: 0.9915
# Epoch 45/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0175 - accuracy: 0.9933 - val_loss: 0.0291 - val_accuracy: 0.9905
# Epoch 46/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0167 - accuracy: 0.9938 - val_loss: 0.0282 - val_accuracy: 0.9917
# Epoch 47/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0168 - accuracy: 0.9936 - val_loss: 0.0262 - val_accuracy: 0.9921
# Epoch 48/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0173 - accuracy: 0.9936 - val_loss: 0.0258 - val_accuracy: 0.9922
# Epoch 49/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0163 - accuracy: 0.9936 - val_loss: 0.0259 - val_accuracy: 0.9916
# Epoch 50/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0174 - accuracy: 0.9935 - val_loss: 0.0283 - val_accuracy: 0.9917
# Epoch 51/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0168 - accuracy: 0.9937 - val_loss: 0.0315 - val_accuracy: 0.9900
# Epoch 52/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0168 - accuracy: 0.9934 - val_loss: 0.0276 - val_accuracy: 0.9924
# Epoch 53/100
# 1882/1882 [==============================] - 15s 8ms/step - loss: 0.0165 - accuracy: 0.9936 - val_loss: 0.0253 - val_accuracy: 0.9919
# Epoch 54/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0162 - accuracy: 0.9938 - val_loss: 0.0246 - val_accuracy: 0.9917
# Epoch 55/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0165 - accuracy: 0.9937 - val_loss: 0.0286 - val_accuracy: 0.9911
# Epoch 56/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.0266 - val_accuracy: 0.9912
# Epoch 57/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.0301 - val_accuracy: 0.9915
# Epoch 58/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0160 - accuracy: 0.9938 - val_loss: 0.0287 - val_accuracy: 0.9918
# Epoch 59/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.0265 - val_accuracy: 0.9925
# Epoch 60/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0159 - accuracy: 0.9940 - val_loss: 0.0277 - val_accuracy: 0.9919
# Epoch 61/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0159 - accuracy: 0.9939 - val_loss: 0.0267 - val_accuracy: 0.9918
# Epoch 62/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.0268 - val_accuracy: 0.9919
# Epoch 63/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0158 - accuracy: 0.9942 - val_loss: 0.0295 - val_accuracy: 0.9922
# Epoch 64/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0155 - accuracy: 0.9941 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 65/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0162 - accuracy: 0.9938 - val_loss: 0.0260 - val_accuracy: 0.9918
# Epoch 66/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0154 - accuracy: 0.9939 - val_loss: 0.0269 - val_accuracy: 0.9930
# Epoch 67/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 0.0286 - val_accuracy: 0.9922
# Epoch 68/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.0259 - val_accuracy: 0.9929
# Epoch 69/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0142 - accuracy: 0.9944 - val_loss: 0.0275 - val_accuracy: 0.9919
# Epoch 70/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0152 - accuracy: 0.9941 - val_loss: 0.0262 - val_accuracy: 0.9933
# Epoch 71/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.0303 - val_accuracy: 0.9915
# Epoch 72/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0155 - accuracy: 0.9943 - val_loss: 0.0302 - val_accuracy: 0.9912
# Epoch 73/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0152 - accuracy: 0.9942 - val_loss: 0.0286 - val_accuracy: 0.9920
# Epoch 74/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0153 - accuracy: 0.9941 - val_loss: 0.0297 - val_accuracy: 0.9926
# Epoch 75/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0145 - accuracy: 0.9943 - val_loss: 0.0295 - val_accuracy: 0.9926
# Epoch 76/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0150 - accuracy: 0.9943 - val_loss: 0.0274 - val_accuracy: 0.9924
# Epoch 77/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0155 - accuracy: 0.9943 - val_loss: 0.0270 - val_accuracy: 0.9929
# Epoch 78/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0144 - accuracy: 0.9944 - val_loss: 0.0273 - val_accuracy: 0.9933
# Epoch 79/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0144 - accuracy: 0.9945 - val_loss: 0.0342 - val_accuracy: 0.9923
# Epoch 80/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0141 - accuracy: 0.9944 - val_loss: 0.0278 - val_accuracy: 0.9936
# Epoch 81/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0139 - accuracy: 0.9947 - val_loss: 0.0283 - val_accuracy: 0.9929
# Epoch 82/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0148 - accuracy: 0.9945 - val_loss: 0.0263 - val_accuracy: 0.9931
# Epoch 83/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.0298 - val_accuracy: 0.9929
# Epoch 84/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0145 - accuracy: 0.9944 - val_loss: 0.0290 - val_accuracy: 0.9929
# Epoch 85/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0133 - accuracy: 0.9949 - val_loss: 0.0315 - val_accuracy: 0.9928
# Epoch 86/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0143 - accuracy: 0.9945 - val_loss: 0.0298 - val_accuracy: 0.9926
# Epoch 87/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.0298 - val_accuracy: 0.9931
# Epoch 88/100
# 1882/1882 [==============================] - 18s 10ms/step - loss: 0.0135 - accuracy: 0.9949 - val_loss: 0.0382 - val_accuracy: 0.9912
# Epoch 89/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0146 - accuracy: 0.9946 - val_loss: 0.0293 - val_accuracy: 0.9934
# Epoch 90/100
# 1882/1882 [==============================] - 18s 9ms/step - loss: 0.0140 - accuracy: 0.9947 - val_loss: 0.0309 - val_accuracy: 0.9915
# Epoch 91/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0149 - accuracy: 0.9944 - val_loss: 0.0271 - val_accuracy: 0.9926
# Epoch 92/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0141 - accuracy: 0.9947 - val_loss: 0.0287 - val_accuracy: 0.9919
# Epoch 93/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0302 - val_accuracy: 0.9921
# Epoch 94/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 0.0290 - val_accuracy: 0.9922
# Epoch 95/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0144 - accuracy: 0.9947 - val_loss: 0.0313 - val_accuracy: 0.9924
# Epoch 96/100
# 1882/1882 [==============================] - 16s 8ms/step - loss: 0.0147 - accuracy: 0.9944 - val_loss: 0.0306 - val_accuracy: 0.9927
# Epoch 97/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0135 - accuracy: 0.9950 - val_loss: 0.0294 - val_accuracy: 0.9926
# Epoch 98/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0133 - accuracy: 0.9948 - val_loss: 0.0290 - val_accuracy: 0.9928
# Epoch 99/100
# 1882/1882 [==============================] - 17s 9ms/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 0.0300 - val_accuracy: 0.9937
# Epoch 100/100
# 1882/1882 [==============================] - 16s 9ms/step - loss: 0.0138 - accuracy: 0.9949 - val_loss: 0.0323 - val_accuracy: 0.9928
# 807/807 [==============================] - 4s 4ms/step
# Accuracy: 0.9926359443432425
# Precision: 0.9926686645086076
# F1-score: 0.9926428763215958
# Confusion Matrix:
# [[11453    13    14    67    12]
#  [    3  7947     0     0     0]
#  [   23     2  2071     0     1]
#  [   27     0     1  2014    24]
#  [    1     0     0     2  2126]]

# %%
evaluate_model(model, x_test, y_test)
# Out:
# 807/807 [==============================] - 3s 3ms/step
# Accuracy: 0.9926359443432425
# Precision: 0.9926686645086076
# F1-score: 0.9926428763215958
#
#
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     11559
#            1       1.00      1.00      1.00      7950
#            2       0.99      0.99      0.99      2097
#            3       0.97      0.97      0.97      2066
#            4       0.98      1.00      0.99      2129
#
#     accuracy                           0.99     25801
#    macro avg       0.99      0.99      0.99     25801
# weighted avg       0.99      0.99      0.99     25801

# %%
model.save(path +"Cnn_lstm input_113 the best of all time 99-28.h5")

# %%
from sklearn.metrics import classification_report

# Assuming you have ground truth labels (y_true) and predicted labels (y_pred)
# Obtain your predictions using your trained model

# Generate the classification report
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)
report = classification_report(y_test, y_pred)

# Print the report
print(report)
# Out:
# 807/807 [==============================] - 4s 5ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     11559
#            1       1.00      1.00      1.00      7950
#            2       0.99      0.99      0.99      2097
#            3       0.97      0.97      0.97      2066
#            4       0.98      1.00      0.99      2129
#
#     accuracy                           0.99     25801
#    macro avg       0.99      0.99      0.99     25801
# weighted avg       0.99      0.99      0.99     25801

# %% [markdown]
# ### LSTM

# %%
lstm = Sequential()
lstm.add(Dense(64, activation='relu', input_shape=(112,1)))
lstm.add(LSTM(128, return_sequences=True))
lstm.add(LSTM(64, return_sequences=True))
lstm.add(LSTM(64))
lstm.add(Dense(256, activation='relu'))
lstm.add(Dropout(0.5))
lstm.add(Dense(5, activation='softmax'))
    
lstm.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
lstm.summary()

# Train the cnn_lstm
history = lstm.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(lstm, x_test, y_test)
