# %% [markdown]
# NSL-KDD Multi-class 5
# ---
#
# Accuracy: 0.9757184750733138
#
# Precision: 0.9760675860882271
#
# F1-score: 0.9758048763891708

# %% [markdown]
# #Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)

# %% [markdown]
# #Data

# %%
features = ['duration','protocol_type','service','flag','src_bytes','dst_bytes','land','wrong_fragment','urgent','hot',
            'num_failed_logins','logged_in','num_compromised','root_shell','su_attempted','num_root','num_file_creations',
            'num_shells','num_access_files','num_outbound_cmds','is_host_login','is_guest_login','count','srv_count','serror_rate',
            'srv_serror_rate','rerror_rate','srv_rerror_rate','same_srv_rate','diff_srv_rate','srv_diff_host_rate','dst_host_count',
            'dst_host_srv_count','dst_host_same_srv_rate','dst_host_diff_srv_rate','dst_host_same_src_port_rate',
            'dst_host_srv_diff_host_rate','dst_host_serror_rate','dst_host_srv_serror_rate','dst_host_rerror_rate',
            'dst_host_srv_rerror_rate','class','difficulty_level']

# %%
from google.colab import drive
drive.mount('/content/drive')
train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/KDDTrain+.txt", names = features)
test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/KDDTest+.txt", names = features)

print(train_df.shape)
print(test_df.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (125967, 43)
# (22549, 43)

# %%
#combining train and test files (there's an error when doing the one hot encoding)
data = pd.concat([train_df, test_df])
print(data.shape)
data.head()
# Out:
# (148516, 43)
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# 2                    0.05                         0.00
# 3                    0.00                         0.03
# 4                    0.00                         0.00
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         0.00                  0.00
# 1                         0.00                  0.00
# 2                         0.00                  1.00
# 3                         0.04                  0.03
# 4                         0.00                  0.00
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                      0.00                  0.05                      0.00
# 1                      0.00                  0.00                      0.00
# 2                      1.00                  0.00                      0.00
# 3                      0.01                  0.00                      0.01
# 4                      0.00                  0.00                      0.00
#
#      class  difficulty_level
# 0   normal                20
# 1   normal                15
# 2  neptune                19
# 3   normal                21
# 4   normal                21
#
# [5 rows x 43 columns]

# %%
data.info()

""" 
  'protocol_type','srevice', 'flag' : categorical types
  'difficulty_level'                : usless
  'class'                           : has multiplie classes of attaks and a normal class
  
  'is_host_login','land', 'logged_in','is_guest_login' : binary no need for normalizing
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148516 entries, 0 to 22548
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148516 non-null  int64
#  1   protocol_type                148516 non-null  object
#  2   service                      148516 non-null  object
#  3   flag                         148516 non-null  object
#  4   src_bytes                    148516 non-null  int64
#  5   dst_bytes                    148516 non-null  int64
#  6   land                         148516 non-null  int64
#  7   wrong_fragment               148516 non-null  int64
#  8   urgent                       148516 non-null  int64
#  9   hot                          148516 non-null  int64
#  10  num_failed_logins            148516 non-null  int64
#  11  logged_in                    148516 non-null  int64
#  12  num_compromised              148516 non-null  int64
#  13  root_shell                   148516 non-null  int64
#  14  su_attempted                 148516 non-null  int64
#  15  num_root                     148516 non-null  int64
#  16  num_file_creations           148516 non-null  int64
#  17  num_shells                   148516 non-null  int64
#  18  num_access_files             148516 non-null  int64
#  19  num_outbound_cmds            148516 non-null  int64
#  20  is_host_login                148516 non-null  int64
#  21  is_guest_login               148516 non-null  int64
#  22  count                        148516 non-null  int64
#  23  srv_count                    148516 non-null  int64
#  24  serror_rate                  148516 non-null  float64
#  25  srv_serror_rate              148516 non-null  float64
#  26  rerror_rate                  148516 non-null  float64
#  27  srv_rerror_rate              148516 non-null  float64
#  28  same_srv_rate                148516 non-null  float64
#  29  diff_srv_rate                148516 non-null  float64
#  30  srv_diff_host_rate           148516 non-null  float64
#  31  dst_host_count               148516 non-null  int64
#  32  dst_host_srv_count           148516 non-null  int64
#  33  dst_host_same_srv_rate       148516 non-null  float64
#  34  dst_host_diff_srv_rate       148516 non-null  float64
#  35  dst_host_same_src_port_rate  148516 non-null  float64
#  36  dst_host_srv_diff_host_rate  148516 non-null  float64
#  37  dst_host_serror_rate         148516 non-null  float64
#  38  dst_host_srv_serror_rate     148516 non-null  float64
#  39  dst_host_rerror_rate         148516 non-null  float64
#  40  dst_host_srv_rerror_rate     148516 non-null  float64
#  41  class                        148516 non-null  object
#  42  difficulty_level             148516 non-null  int64
# dtypes: float64(15), int64(24), object(4)
# memory usage: 49.9+ MB
# " \n  'protocol_type','srevice', 'flag' : categorical types\n  'difficulty_level'                : usless\n  'class'                           : has multiplie classes of attaks and a normal class\n  \n  'is_host_login','land', 'logged_in','is_guest_login' : binary no need for normalizing\n"

# %%
#some stats
data.describe().style.background_gradient(cmap='Blues').set_properties(**{'font-family':'Segoe UI'})
# Out:
# <style type="text/css">
# #T
;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_72b29_row7_col9, #T_72b29_row7_col12 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_72b29" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72b29_level0_col0" class="col_heading level0 col0" >duration</th>
#       <th id="T_72b29_level0_col1" class="col_heading level0 col1" >src_bytes</th>
#       <th id="T_72b29_level0_col2" class="col_heading level0 col2" >dst_bytes</th>
#       <th id="T_72b29_level0_col3" class="col_heading level0 col3" >land</th>
#       <th id="T_72b29_level0_col4" class="col_heading level0 col4" >wrong_fragment</th>
#       <th id="T_72b29_level0_col5" class="col_heading level0 col5" >urgent</th>
#       <th id="T_72b29_level0_col6" class="col_heading level0 col6" >hot</th>
#       <th id="T_72b29_level0_col7" class="col_heading level0 col7" >num_failed_logins</th>
#       <th id="T_72b29_level0_col8" class="col_heading level0 col8" >logged_in</th>
#       <th id="T_72b29_level0_col9" class="col_heading level0 col9" >num_compromised</th>
#       <th id="T_72b29_level0_col10" class="col_heading level0 col10" >root_shell</th>
#       <th id="T_72b29_l

# %% [markdown]
# ### fixing labels

# %%
#Actual labels
print(data['class'].value_counts())
# Out:
# normal             77054
# neptune            45871
# satan               4367
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# loadmodule            11
# ftp_write             11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: class, dtype: int64

# %%
#fixing labels

dos_class =["apache2","back","land","neptune","mailbomb","pod","processtable","smurf","teardrop","udpstorm","worm"]
R2L_class =["ftp_write","guess_passwd","httptunnel","imap","multihop","named","phf","sendmail","snmpgetattack","spy","snmpguess","warezclient","warezmaster","xlock","xsnoop"]      
Probe_class =["ipsweep","mscan","nmap","portsweep","saint","satan"]
U2R_class =["buffer_overflow","loadmodule","perl","ps","rootkit","sqlattack","xterm"]

for atk in dos_class:
  data.loc[data['class'] == atk, 'class'] = 'DoS'
for atk in R2L_class: 
  data.loc[data['class'] == atk, 'class'] = 'R2L'
for atk in Probe_class: 
  data.loc[data['class'] == atk, 'class'] = 'Probe'
for atk in U2R_class :
  data.loc[data['class'] == atk, 'class'] = "U2R"

data['class'].value_counts()
# Out:
# normal    77054
# DoS       53387
# Probe     14076
# R2L        3880
# U2R         119
# Name: class, dtype: int64

# %% [markdown]
# ##Data visualisation

# %% [markdown]
# ###Repartition des classes

# %%
data['class'].value_counts().plot(kind = "pie" ,figsize=(5, 5), fontsize=10, autopct='%1.0f%%')
# Out:
# <Axes: ylabel='class'>

# %%
#data.plot(kind='box',subplots=True,layout=(6,8),figsize=(20,40))
plt.show()

# %% [markdown]
# need to check:
# correlation between features,

# %%
# instances dupliquées 
print(data.duplicated().sum())
# Out:
# 629

# %%
# colones ayant la meme valuers
unique_counts = data.nunique()
columns = unique_counts[unique_counts == 1].index.tolist()
columns
# Out:
# ['num_outbound_cmds']

# %%
# verifier les valeurs manquantes
missing_values = data.isnull().any(axis=1)

if missing_values.any():
    print("There are instances with missing values:")
    print(data[missing_values])
else:
    print("There are no instances with missing values.")
# Out:
# There are no instances with missing values.

# %%
# paires d'attributs ayant une correlation elvée
# Calculate the correlation matrix
corr_matrix = data.corr()

# Find unique attribute pairs with correlation above 0.90
high_corr_pairs = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i, j]) > 0.90:
            pair = (corr_matrix.columns[i], corr_matrix.columns[j])
            high_corr_pairs.add(tuple(sorted(pair)))

# Print the unique attribute pairs with high correlation
count = 0
for pair in high_corr_pairs:
    count +=1
    print(f"Attributes '{pair[0]}' and '{pair[1]}' have correlation above 0.90.")
print (count)
# Out:
# <ipython-input-92-ef086dcb6e83>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
# Attributes 'serror_rate' and 'srv_serror_rate' have correlation above 0.90.
# Attributes 'num_compromised' and 'num_root' have correlation above 0.90.
# Attributes 'dst_host_rerror_rate' and 'srv_rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_rerror_rate' and 'rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'serror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_rerror_rate' and 'srv_rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_rerror_rate' and 'rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_serror_rate' and 'serror_rate' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'srv_serror_rate' have correlation above 0.90.
# Attributes 'dst_host_rerror_rate' and 'dst_host_srv_rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_serror_rate' and 'dst_host_srv_serror_rate' have correlation above 0.90.
# Attributes 'rerror_rate' and 'srv_rerror_rate' have correlation above 0.90.
# Attributes 'dst_host_srv_serror_rate' and 'srv_serror_rate' have correlation above 0.90.
# 13

# %% [markdown]
# # prétraitement

# %%
data
# Out:
#        duration protocol_type    service flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   ftp_data   SF        491          0     0
# 1             0           udp      other   SF        146          0     0
# 2             0           tcp    private   S0          0          0     0
# 3             0           tcp       http   SF        232       8153     0
# 4             0           tcp       http   SF        199        420     0
# ...         ...           ...        ...  ...        ...        ...   ...
# 22544         0          icmp      red_i   SF         91          0     0
# 22545         0          icmp      urh_i   SF         36          0     0
# 22546         0           tcp  http_8001   S0          0          0     0
# 22547         0           tcp        aol  REJ          0          0     0
# 22548         0           tcp    harvest   S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                   0       0    0  ...                    0.17
# 1                   0       0    0  ...                    0.00
# 2                   0       0    0  ...                    0.10
# 3                   0       0    0  ...                    1.00
# 4                   0       0    0  ...                    1.00
# ...               ...     ...  ...  ...                     ...
# 22544               0       0    0  ...                    0.01
# 22545               0       0    0  ...                    0.14
# 22546               0       0    0  ...                    0.00
# 22547               0       0    0  ...                    0.00
# 22548               0       0    0  ...                    0.00
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                        0.03                         0.17
# 1                        0.60                         0.88
# 2                        0.05                         0.00
# 3                        0.00                         0.03
# 4                        0.00                         0.00
# ...                       ...                          ...
# 22544                    0.02                         0.01
# 22545                    0.07                         0.14
# 22546                    1.00                         0.00
# 22547                    1.00                         0.00
# 22548                    1.00                         0.00
#
#        dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                             0.00                  0.00
# 1                             0.00                  0.00
# 2                             0.00                  1.00
# 3                             0.04                  0.03
# 4                             0.00                  0.00
# ...                            ...                   ...
# 22544                         0.00                  0.00
# 22545                         0.00                  0.00
# 22546                         0.00                  0.13
# 22547                         0.00                  0.03
# 22548                         0.00                  0.17
#
#        dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                          0.00                  0.05
# 1                          0.00                  0.00
# 2                          1.00                  0.00
# 3                          0.01                  0.00
# 4                          0.00                  0.00
# ...                         ...                   ...
# 22544                      0.00                  0.11
# 22545                      0.00                  0.00
# 22546                      1.00                  0.87
# 22547                      0.00                  0.97
# 22548                      1.00                  0.82
#
#        dst_host_srv_rerror_rate   class  difficulty_level
# 0                          0.00  normal                20
# 1                          0.00  normal                15
# 2                          0.00     DoS                19
# 3                          0.01  normal                21
# 4                          0.00  normal                21
# ...                         ...     ...               ...
# 22544                      0.00  normal                20
# 22545                      0.00  normal                21
# 22546                      0.00   Probe                17
# 22547                      1.00   Probe                17
# 22548                      0.00   Probe                17
#
# [148516 rows x 43 columns]

# %%
# remove column with the same value
data.drop('num_outbound_cmds', axis=1, inplace=True)

# List of columns to remove
columns_to_remove = ['serror_rate', 'num_compromised', 'dst_host_rerror_rate',
                     'dst_host_srv_rerror_rate', 'dst_host_serror_rate',
                     'rerror_rate', 'dst_host_srv_serror_rate']

# Remove the specified columns
data = data.drop(columns=columns_to_remove, axis = 1)

# %%
data
# Out:
#        duration protocol_type    service flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   ftp_data   SF        491          0     0
# 1             0           udp      other   SF        146          0     0
# 2             0           tcp    private   S0          0          0     0
# 3             0           tcp       http   SF        232       8153     0
# 4             0           tcp       http   SF        199        420     0
# ...         ...           ...        ...  ...        ...        ...   ...
# 22544         0          icmp      red_i   SF         91          0     0
# 22545         0          icmp      urh_i   SF         36          0     0
# 22546         0           tcp  http_8001   S0          0          0     0
# 22547         0           tcp        aol  REJ          0          0     0
# 22548         0           tcp    harvest   S0          0          0     0
#
#        wrong_fragment  urgent  hot  ...  diff_srv_rate  srv_diff_host_rate  \
# 0                   0       0    0  ...           0.00                0.00
# 1                   0       0    0  ...           0.15                0.00
# 2                   0       0    0  ...           0.07                0.00
# 3                   0       0    0  ...           0.00                0.00
# 4                   0       0    0  ...           0.00                0.09
# ...               ...     ...  ...  ...            ...                 ...
# 22544               0       0    0  ...           0.00                0.00
# 22545               0       0    0  ...           0.00                0.00
# 22546               0       0    0  ...           1.00                0.00
# 22547               0       0    0  ...           1.00                0.00
# 22548               0       0    0  ...           1.00                0.00
#
#        dst_host_count  dst_host_srv_count  dst_host_same_srv_rate  \
# 0                 150                  25                    0.17
# 1                 255                   1                    0.00
# 2                 255                  26                    0.10
# 3                  30                 255                    1.00
# 4                 255                 255                    1.00
# ...               ...                 ...                     ...
# 22544             126                   1                    0.01
# 22545              73                  10                    0.14
# 22546             255                   1                    0.00
# 22547             255                   1                    0.00
# 22548             255                   1                    0.00
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                        0.03                         0.17
# 1                        0.60                         0.88
# 2                        0.05                         0.00
# 3                        0.00                         0.03
# 4                        0.00                         0.00
# ...                       ...                          ...
# 22544                    0.02                         0.01
# 22545                    0.07                         0.14
# 22546                    1.00                         0.00
# 22547                    1.00                         0.00
# 22548                    1.00                         0.00
#
#        dst_host_srv_diff_host_rate   class  difficulty_level
# 0                             0.00  normal                20
# 1                             0.00  normal                15
# 2                             0.00     DoS                19
# 3                             0.04  normal                21
# 4                             0.00  normal                21
# ...                            ...     ...               ...
# 22544                         0.00  normal                20
# 22545                         0.00  normal                21
# 22546                         0.00   Probe                17
# 22547                         0.00   Probe                17
# 22548                         0.00   Probe                17
#
# [148516 rows x 35 columns]

# %% [markdown]
# ##### 1-Normalisation (Robuste)

# %%
#les colonnes doivent etre numeriques seulement
def normalisation(dataframe, columns):
  normalised_df = pd.DataFrame(RobustScaler().fit_transform(dataframe), columns = columns)
  return normalised_df

# %%
categorical_columns = ['is_host_login','protocol_type','service','flag','land', 'logged_in','is_guest_login', 'difficulty_level', 'class']

# %%
def preprocessing(dataframe):
  #selectionner le valeurs numeriques puis les normaliser
  num_df = dataframe.drop(categorical_columns, axis=1)
  num_cols = num_df.columns
  normalized_df = normalisation(num_df, num_cols)

  #supression des ancienne données numeriques et rajout des données normalisées
  dataframe.drop(labels = num_cols, axis= 'columns', inplace = True)
  dataframe[num_cols] = normalized_df[num_cols]
  df = dataframe
  #remplaces les lables de la colonne 'class": 
  #0 => normal
  #1 => Dos
  #2 => Probe
  #3 => R2L
  #4 => U2R
  dataframe.loc[dataframe['class'] == "normal", "class"]= 0
  dataframe.loc[dataframe['class'] == "DoS", "class"]= 1
  dataframe.loc[dataframe['class'] == "Probe", "class"]= 2
  dataframe.loc[dataframe['class'] == "R2L", "class"]= 3
  dataframe.loc[dataframe['class'] == "U2R", "class"]= 4 

  #onehot encoding
  dataframe = pd.get_dummies(dataframe, columns = ['protocol_type','service', 'flag'])

  return dataframe, df

# %%
normalized_df , df= preprocessing(data)

# %%
# Calculer la matrice de corrélation
corr_matrix = normalized_df.corr()

# Trouver les attributs ayant une forte corrélation
threshold = 0.90  # Définir un seuil de corrélation
high_corr_attrs = []

# Parcourir les paires d'attributs de la matrice de corrélation
for attr1 in corr_matrix.columns:
    for attr2 in corr_matrix.columns:
        if attr1 != attr2 and abs(corr_matrix.loc[attr1, attr2]) > threshold:
            high_corr_attrs.append((attr1, attr2))

# Afficher les attributs ayant une forte corrélation
count = 0
for attr1, attr2 in high_corr_attrs:
    count +=1
    print(f"{attr1} et {attr2} ont une corrélation élevée : {corr_matrix.loc[attr1, attr2]}")
print(count)
# Out:
# <ipython-input-100-44899c4bbf29>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = normalized_df.corr()
# 0

# %% [markdown]
# #####Data augmentation

# %%
#code to augment some classes
normalized_df['class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
minority_classes = [ 2 , 3 , 4]
mask = normalized_df['class'].isin(minority_classes)
minority_df = normalized_df[mask]
minority_df
# Out:
#        land  logged_in  is_host_login  is_guest_login class  difficulty_level  \
# 13        0          1              0               0     3                15
# 17        0          0              0               0     2                18
# 30        0          0              0               0     2                17
# 33        0          0              0               0     2                20
# 48        0          1              0               0     3                12
# ...     ...        ...            ...             ...   ...               ...
# 22524     0          1              0               0     4                 4
# 22543     0          0              0               0     2                14
# 22546     0          0              0               0     2                17
# 22547     0          0              0               0     2                17
# 22548     0          0              0               0     2                17
#
#        duration  src_bytes  dst_bytes  wrong_fragment  ...  flag_REJ  \
# 13          0.0   1.043165   0.000000             0.0  ...         0
# 17          0.0  -0.093525   0.000000             0.0  ...         0
# 30          0.0  -0.129496   0.000000             0.0  ...         0
# 33          0.0  -0.158273   0.000000             0.0  ...         1
# 48          0.0   1.043165   0.000000             0.0  ...         0
# ...         ...        ...        ...             ...  ...       ...
# 22524       0.0   0.640288   1.073555             0.0  ...         0
# 22543       0.0   3.553957   0.000000             0.0  ...         1
# 22546       0.0  -0.158273   0.000000             0.0  ...         0
# 22547       0.0   0.870504   1.602452             0.0  ...         1
# 22548       0.0   0.071942   0.000000             0.0  ...         0
#
#        flag_RSTO  flag_RSTOS0  flag_RSTR  flag_S0  flag_S1  flag_S2  flag_S3  \
# 13             0            0          0        0        0        0        0
# 17             0            0          0        0        0        0        0
# 30             0            0          0        0        0        0        0
# 33             0            0          0        0        0        0        0
# 48             0            0          0        0        0        0        0
# ...          ...          ...        ...      ...      ...      ...      ...
# 22524          0            0          0        0        0        0        0
# 22543          0            0          0        0        0        0        0
# 22546          0            0          0        1        0        0        0
# 22547          0            0          0        0        0        0        0
# 22548          0            0          0        1        0        0        0
#
#        flag_SF  flag_SH
# 13           1        0
# 17           1        0
# 30           1        0
# 33           0        0
# 48           1        0
# ...        ...      ...
# 22524        1        0
# 22543        0        0
# 22546        0        0
# 22547        0        0
# 22548        0        0
#
# [18075 rows x 115 columns]

# %%
#code--
from imblearn.over_sampling import SMOTE

minority = minority_df.drop(['difficulty_level'], axis = 1)
xm = minority.drop(['class'], axis = 1)
ym = minority['class']

smote = SMOTE()
augmented_x, augmented_y = smote.fit_resample(xm.values,ym.values.astype('int'))

# %%
original_df = normalized_df
xmc = pd.DataFrame(xm).columns
ymc = pd.DataFrame(ym).columns
augmented = pd.concat([pd.DataFrame(augmented_x, columns=xmc), pd.DataFrame(augmented_y, columns = ymc)], axis = 1)
normalized_df = pd.concat([pd.DataFrame(normalized_df.drop(['difficulty_level'], axis = 1)), augmented])
normalized_df['class'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ##### Feature selection (reduction) PCA

# %%
normalized_df = normalized_df.drop_duplicates()
normalized_df = normalized_df.sample(frac = 1, random_state = 42)
normalized_df = normalized_df.reset_index(drop = True)

# %%
#Extraction des X et Y
x = normalized_df.drop(['class'], axis = 1).values
y = normalized_df['class'].values.astype('int')

#initialisation PCA
pca = PCA(n_components = 108)
pca = pca.fit(x)
x_r = pca.transform(x)

print("# Of original features: ", x.shape[1])
print("# Features after reduction: ", x_r.shape[1])
# Out:
# # Of original features:  113
# # Features after reduction:  108

# %%
#Training splits
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size = 0.5, random_state = 42)

#reduced features splits
xr_train, xr_test, yr_train, yr_test = train_test_split(x_r, y, test_size = 0.3, random_state = 42)
xr_val, xr_test, yr_val, yr_test = train_test_split(xr_test, yr_test, test_size = 0.5, random_state = 42)

print("x_train shape : ", x_train.shape)
print("y_train shape : ", y_train.shape)

print("x_test shape : ", x_test.shape)
print("y_test shape : ", y_test.shape)
# Out:
# x_train shape :  (118044, 113)
# y_train shape :  (118044,)
# x_test shape :  (25296, 113)
# y_test shape :  (25296,)

# %% [markdown]
# #Models and evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix

evaluations = {}

def evaluate_model(model, X_test, y_true):
    # Step 2: Make predictions
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Step 3: Calculate accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Step 4: Calculate precision
    precision = precision_score(y_true, y_pred, average='weighted')

    # Step 5: Calculate F1-score
    f1score = f1_score(y_true, y_pred, average='weighted')

    # Step 6: Calculate confusion matrix
    confusion_mat = confusion_matrix(y_true, y_pred)

    # Print evaluation metrics
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("F1-score:", f1score)
    print("Confusion Matrix:")
    print(confusion_mat)

# %% [markdown]
# # Models

# %%
"""from sklearn.neighbors import KNeighborsClassifier
KNN= KNeighborsClassifier(n_neighbors=6) 
KNN.fit(x_train, y_train)

print(KNN.score(x_train, y_train))
print(KNN.score(x_test, y_test))
"""
# Out:
# 'from sklearn.neighbors import KNeighborsClassifier\nKNN= KNeighborsClassifier(n_neighbors=6) \nKNN.fit(x_train, y_train)\n\nprint(KNN.score(x_train, y_train))\nprint(KNN.score(x_test, y_test))\n'

# %% [markdown]
# ### CNN

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

CNN = Sequential()
CNN.add(Conv1D(32, 3, activation='relu', input_shape=(113,1)))
CNN.add(Conv1D(64, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Flatten())
CNN.add(Dense(256, activation='relu'))
CNN.add(Dropout(0.5))
CNN.add(Dense(5, activation='softmax'))
CNN.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
CNN.summary()

# Train the CNN
history = CNN.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(CNN, x_test, y_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_8 (Conv1D)           (None, 111, 32)           128
#
#  conv1d_9 (Conv1D)           (None, 109, 64)           6208
#
#  max_pooling1d_4 (MaxPooling  (None, 54, 64)           0
#  1D)
#
#  conv1d_10 (Conv1D)          (None, 52, 128)           24704
#
#  conv1d_11 (Conv1D)          (None, 50, 128)           49280
#
#  max_pooling1d_5 (MaxPooling  (None, 25, 128)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 3200)              0
#
#  dense_4 (Dense)             (None, 256)               819456
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params:
50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0652 - accuracy: 0.9777 - val_loss: 0.0880 - val_accuracy: 0.9732
# Epoch 30/50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0668 - accuracy: 0.9777 - val_loss: 0.0851 - val_accuracy: 0.9741
# Epoch 31/50
# 1845/1845 [==============================] - 11s 6ms/step - loss: 0.0648 - accuracy: 0.9777 - val_loss: 0.0921 - val_accuracy: 0.9733
# Epoch 32/50
# 1845/1845 [==============================] - 11s 6ms/step - loss: 0.0700 - accuracy: 0.9776 - val_loss: 0.1115 - val_accuracy: 0.9702
# Epoch 33/50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0651 - accuracy: 0.9778 - val_loss: 0.0888 - val_accuracy: 0.9743
# Epoch 34/50
# 1845/1845 [==============================] - 12s 7ms/step - loss: 0.0970 - accuracy: 0.9785 - val_loss: 0.0929 - val_accuracy: 0.9733
# Epoch 35/50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0645 - accuracy: 0.9787 - val_loss: 0.0943 - val_accuracy: 0.9737
# Epoch 36/50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0748 - accuracy: 0.9788 - val_loss: 0.0923 - val_accuracy: 0.9732
# Epoch 37/50
# 1845/1845 [==============================] - 11s 6ms/step - loss: 0.0667 - accuracy: 0.9786 - val_loss: 0.0854 - val_accuracy: 0.9739
# Epoch 38/50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0627 - accuracy: 0.9787 - val_loss: 0.1049 - val_accuracy: 0.9731
# Epoch 39/50
# 1845/1845 [==============================] - 12s 7ms/step - loss: 0.0655 - accuracy: 0.9786 - val_loss: 0.0971 - val_accuracy: 0.9734
# Epoch 40/50
# 1845/1845 [==============================] - 14s 8ms/step - loss: 0.0609 - accuracy: 0.9794 - val_loss: 0.0912 - val_accuracy: 0.9736
# Epoch 41/50
# 1845/1845 [==============================] - 12s 7ms/step - loss: 0.0648 - accuracy: 0.9791 - val_loss: 0.0926 - val_accuracy: 0.9740
# Epoch 42/50
# 1845/1845 [==============================] - 12s 7ms/step - loss: 0.0607 - accuracy: 0.9797 - val_loss: 0.0899 - val_accuracy: 0.9743
# Epoch 43/50
# 1845/1845 [==============================] - 12s 6ms/step - loss: 0.0621 - accuracy: 0.9795 - val_loss: 0.0985 - val_accuracy: 0.9745
# Epoch 44/50
# 1845/1845 [==============================] - 11s 6ms/step - loss: 0.0608 - accuracy: 0.9793 - val_loss: 0.0938 - val_accuracy: 0.9744
# Epoch 45/50
# 1845/1845 [==============================] - 12s 7ms/step - loss: 0.0591 - accuracy: 0.9798 - val_loss: 0.0946 - val_accuracy: 0.9741
# Epoch 46/50
# 1845/1845 [==============================] - 13s 7ms/step - loss: 0.0626 - accuracy: 0.9796 - val_loss: 0.0900 - val_accuracy: 0.9748
# Epoch 47/50
# 1845/1845 [==============================] - 12s 7ms/step - loss: 0.0586 - accuracy: 0.9805 - val_loss: 0.0965 - val_accuracy: 0.9734
# Epoch 48/50
# 1845/1845 [==============================] - 13s 7ms/step - loss: 0.0579 - accuracy: 0.9804 - val_loss: 0.0934 - val_accuracy: 0.9729
# Epoch 49/50
# 1845/1845 [==============================] - 13s 7ms/step - loss: 0.0614 - accuracy: 0.9801 - val_loss: 0.0973 - val_accuracy: 0.9735
# Epoch 50/50
# 1845/1845 [==============================] - 13s 7ms/step - loss: 0.0568 - accuracy: 0.9804 - val_loss: 0.1033 - val_accuracy: 0.9737
# 791/791 [==============================] - 2s 2ms/step
# Accuracy: 0.9752925363693865
# Precision: 0.9757799512252404
# F1-score: 0.9754461722178743
# Confusion Matrix:
# [[11057    18    28   145     7]
#  [  112  7710    33    54     0]
#  [   16    58  1789    40     0]
#  [   49    22    35  2018     2]
#  [    0     0     0     6  2097]]

# %%
CNN.save("Cnn precision_09715 input_113 .h5")
