# %% [markdown]
# #Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
config = "multi_noncombined"

# %% [markdown]
# #Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_set = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/multi/KDDTrain_multi_noncombined.txt")
val_set = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/multi/KDDVal_multi_noncombined.txt")
test_set = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nslkdd/multi/KDDTest_multi_noncombined.txt")

# séparation en x et y

x_train = train_set.drop(columns = ["class"])
x_val = val_set.drop(columns = ["class"])
x_test = test_set.drop(columns = ["class"])

y_train = train_set["class"]
y_val = val_set["class"]
y_test = test_set["class"]

#PCA
#initialisation PCA
#faut regler les parametres n_componenets

pca = PCA(n_components = 30)
pca = pca.fit(x_train)
x_train_pca = pca.transform(x_train)
x_val_pca = pca.transform(x_val)
x_test_pca = pca.transform(x_test)

print("# Of original features: ", x_train.shape[1])
print("# Features after reduction: ", x_train_pca.shape[1])
print("y_train shape", y_train.shape)
print("x_train shape", x_train.shape)

y_train.value_counts()
# Out:
# # Of original features:  116
# # Features after reduction:  30
# y_train shape (88170,)
# x_train shape (88170, 116)
# 0    47332
# 1    32092
# 2     8044
# 3      667
# 4       35
# Name: class, dtype: int64

# %% [markdown]
# #Models and evaluation

# %% [markdown]
# #### Fonction d'evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score, confusion_matrix, classification_report
import seaborn as sns

def evaluate_model(model, X_test, y_true):
    # Step 2: Make predictions
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)

    # Step 3: Calculate accuracy
    accuracy = accuracy_score(y_true, y_pred)

    # Step 4: Calculate precision
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=1)

    # Step 5: Calculate F1-score
    f1score = f1_score(y_true, y_pred, average='weighted', zero_division=1)

    # Step 6: Calculate Recall
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=1)

    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1score)

    # Generate the classification report
    classes = ['Normal', 'DoS', 'Probe', 'R2L', 'U2R']
    print("\n\n",classification_report(y_test, y_pred))

    # Step 6: Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)


    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(4, 3))

    # Plot the confusion matrix as a heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax)

    # Set labels and title

    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix')

    # Set x-axis and y-axis tick labels
    ax.xaxis.set_ticklabels(classes)
    ax.yaxis.set_ticklabels(classes)

    # Rotate the tick labels for better visibility
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)

    # Display the plot
    plt.show()

    num_classes = cm.shape[0]
    for class_idx in range(num_classes):
        row = cm[class_idx]

        tn = np.sum(np.delete(np.delete(cm, class_idx, axis=0), class_idx, axis=1))
        fp = np.sum(row) - cm[class_idx, class_idx]
        fn = np.sum(row) - cm[class_idx, class_idx]
        tp = cm[class_idx, class_idx]

        false_positive_rate = fp / (fp + tn)
        false_negative_rate = fn / (fn + tp)

        print("Class:", class_idx)
        print("False Positive Rate:", false_positive_rate)
        print("False Negative Rate:", false_negative_rate)
        print()

# %%
import matplotlib.pyplot as plt

def plot_metrics_comparison(history1, name1, history2, name2):
    # Extracting metrics from history objects
    accuracy1 = history1.history['accuracy']
    val_accuracy1 = history1.history['val_accuracy']
    loss1 = history1.history['loss']
    val_loss1 = history1.history['val_loss']

    accuracy2 = history2.history['accuracy']
    val_accuracy2 = history2.history['val_accuracy']
    loss2 = history2.history['loss']
    val_loss2 = history2.history['val_loss']

    # Creating subplots
    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    # Plotting accuracy
    axs[0].plot(accuracy1, label=name1+' Training Accuracy')
    axs[0].plot(val_accuracy1, label=name1+' Validation Accuracy')
    axs[0].plot(accuracy2, label=name2 +' Training Accuracy')
    axs[0].plot(val_accuracy2, label=name2 +' Validation Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_title('Accuracy Comparison')
    axs[0].legend()

    # Plotting loss
    axs[1].plot(loss1, label=name1+' Training Loss')
    axs[1].plot(val_loss1, label=name1+' Validation Loss')
    axs[1].plot(loss2, label=name2 +' Training Loss')
    axs[1].plot(val_loss2, label=name2 +' Validation Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].set_title('Loss Comparison')
    axs[1].legend()

    # Adjusting spacing between subplots
    plt.tight_layout()

    # Display the plot
    plt.show()

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

def calculate_metrics(y_true, y_pred):
    """
    Calculate classification metrics for the given true labels and predicted labels.
    Returns a dictionary of metric values.
    """
    metrics = {}
    y_pred =np.argmax(y_pred, axis=1)

    metrics['Accuracy'] = accuracy_score(y_true, y_pred)
    metrics['Recall'] = recall_score(y_true, y_pred, average='weighted', zero_division=1)
    metrics['Precision'] = precision_score(y_true, y_pred, average='weighted', zero_division=1)
    metrics['F1-score'] = f1_score(y_true, y_pred, average='weighted', zero_division=1)

    return metrics

def write_metrics_to_dataframe(configuration_name, metrics_dict, df):
    """
    Write the classification metrics from the metrics dictionary to a DataFrame.
    The metrics are appended as a new row to the given DataFrame along with the configuration name.
    """
    metrics_dict['Configuration'] = configuration_name
    df = df.append(metrics_dict, ignore_index=True)
    return df

# Initializing the DataFrame
columns = ['Configuration', 'Accuracy', 'Recall', 'Precision', 'F1-score']
result_df = pd.DataFrame(columns=columns)

# %% [markdown]
# # Models

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM

# %% [markdown]
# ## final model classification

# %% [markdown]
# ### CNN

# %%
CNN = Sequential()
CNN.add(Conv1D(32, 3, activation='relu', input_shape=(x_train.shape[1],1)))
CNN.add(Conv1D(64, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Dropout(0.2))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(Conv1D(128, 3, activation='relu'))
CNN.add(MaxPooling1D(2))
CNN.add(Dropout(0.2))
CNN.add(Flatten())
CNN.add(Dense(256, activation='relu'))
CNN.add(Dropout(0.5))
CNN.add(Dense(5, activation='sigmoid'))
CNN.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
CNN.summary()

# Train the CNN
history = CNN.fit(x_train, y_train, epochs=80, validation_data=(x_val,y_val),batch_size = 64)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 114, 32)           128
#
#  conv1d_1 (Conv1D)           (None, 112, 64)           6208
#
#  max_pooling1d (MaxPooling1D  (None, 56, 64)           0
#  )
#
#  dropout (Dropout)           (None, 56, 64)            0
#
#  conv1d_2 (Conv1D)           (None, 54, 128)           24704
#
#  conv1d_3 (Conv1D)           (None, 52, 128)           49280
#
#  max_pooling1d_1 (MaxPooling  (None, 26, 128)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 26, 128)           0
#
#  flatten (Flatten)           (None, 3328)              0
#
#  dense (Dense)               (None, 256)               852224
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 933,829
# Trainable params: 933,829
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 1378/1378 [==============================] - 21s 7ms/step - loss: 0.0841 - accuracy: 0.9736 - val_loss: 0.0357 - val_accuracy: 0.9876
# Epoch 2/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.0229 - val_accuracy: 0.9927
# Epoch 3/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.0198 - val_accuracy: 0.9933
# Epoch 4/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 0.0213 - val_accuracy: 0.9933
# Epoch 5/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0181 - accuracy: 0.9938 - val_loss: 0.0185 - val_accuracy: 0.9945
# Epoch 6/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0164 - accuracy: 0.9948 - val_loss: 0.0196 - val_accuracy: 0.9943
# Epoch 7/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0145 - val_accuracy: 0.9956
# Epoch 8/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.0142 - val_accuracy: 0.9952
# Epoch 9/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0141 - val_accuracy: 0.9961
# Epoch 10/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0149 - val_accuracy: 0.9957
# Epoch 11/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0138 - val_accuracy: 0.9959
# Epoch 12/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 0.0162 - val_accuracy: 0.9952
# Epoch 13/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0135 - val_accuracy: 0.9958
# Epoch 14/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0148 - val_accuracy: 0.9957
# Epoch 15/80
# 1378/1378 [==============================] - 10s 8ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0132 - val_accuracy: 0.9956
# Epoch 16/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0118 - val_accuracy: 0.9963
# Epoch 17/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.0130 - val_accuracy: 0.9964
# Epoch 18/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.0115 - val_accuracy: 0.9963
# Epoch 19/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0179 - val_accuracy: 0.9945
# Epoch 20/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.0132 - val_accuracy: 0.9959
# Epoch 21/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0138 - val_accuracy: 0.9965
# Epoch 22/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0160 - val_accuracy: 0.9954
# Epoch 23/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0137 - val_accuracy: 0.9962
# Epoch 24/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0141 - val_accuracy: 0.9961
# Epoch 25/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0125 - val_accuracy: 0.9964
# Epoch 26/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0147 - val_accuracy: 0.9963
# Epoch 27/80
# 1378/1378 [==============================] - 10s 8ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0126 - val_accuracy: 0.9965
# Epoch 28/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0136 - val_accuracy: 0.9964
# Epoch 29/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0166 - val_accuracy: 0.9961
# Epoch 30/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0118 - val_accuracy: 0.9960
# Epoch 31/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0117 - val_accuracy: 0.9963
# Epoch 32/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0127 - val_accuracy: 0.9963
# Epoch 33/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0138 - val_accuracy: 0.9963
# Epoch 34/80
# 1378/1378 [==============================] - 10s 8ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0129 - val_accuracy: 0.9960
# Epoch 35/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0146 - val_accuracy: 0.9964
# Epoch 36/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0145 - val_accuracy: 0.9962
# Epoch 37/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0147 - val_accuracy: 0.9968
# Epoch 38/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0138 - val_accuracy: 0.9965
# Epoch 39/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.0138 - val_accuracy: 0.9964
# Epoch 40/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0149 - val_accuracy: 0.9960
# Epoch 41/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0157 - val_accuracy: 0.9966
# Epoch 42/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0131 - val_accuracy: 0.9967
# Epoch 43/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0129 - val_accuracy: 0.9968
# Epoch 44/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.0137 - val_accuracy: 0.9967
# Epoch 45/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0117 - val_accuracy: 0.9966
# Epoch 46/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0141 - val_accuracy: 0.9966
# Epoch 47/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0164 - val_accuracy: 0.9967
# Epoch 48/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0178 - val_accuracy: 0.9966
# Epoch 49/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0130 - val_accuracy: 0.9965
# Epoch 50/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0158 - val_accuracy: 0.9963
# Epoch 51/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0125 - val_accuracy: 0.9956
# Epoch 52/80
# 1378/1378 [==============================] - 10s 8ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0128 - val_accuracy: 0.9967
# Epoch 53/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0154 - val_accuracy: 0.9965
# Epoch 54/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0170 - val_accuracy: 0.9965
# Epoch 55/80
# 1378/1378 [==============================] - 14s 10ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0127 - val_accuracy: 0.9970
# Epoch 56/80
# 1378/1378 [==============================] - 12s 8ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0152 - val_accuracy: 0.9964
# Epoch 57/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0152 - val_accuracy: 0.9965
# Epoch 58/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0136 - val_accuracy: 0.9968
# Epoch 59/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0181 - val_accuracy: 0.9966
# Epoch 60/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0126 - val_accuracy: 0.9970
# Epoch 61/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0149 - val_accuracy: 0.9966
# Epoch 62/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0157 - val_accuracy: 0.9967
# Epoch 63/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0182 - val_accuracy: 0.9960
# Epoch 64/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0140 - val_accuracy: 0.9968
# Epoch 65/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0125 - val_accuracy: 0.9965
# Epoch 66/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0166 - val_accuracy: 0.9964
# Epoch 67/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0149 - val_accuracy: 0.9967
# Epoch 68/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0120 - val_accuracy: 0.9965
# Epoch 69/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0121 - val_accuracy: 0.9968
# Epoch 70/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0156 - val_accuracy: 0.9966
# Epoch 71/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0128 - val_accuracy: 0.9965
# Epoch 72/80
# 1378/1378 [==============================] - 10s 7ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0141 - val_accuracy: 0.9967
# Epoch 73/80
# 1378/1378 [==============================] - 10s 8ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0150 - val_accuracy: 0.9966
# Epoch 74/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 75/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0114 - val_accuracy: 0.9970
# Epoch 76/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0131 - val_accuracy: 0.9965
# Epoch 77/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0150 - val_accuracy: 0.9966
# Epoch 78/80
# 1378/1378 [==============================] - 9s 6ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0174 - val_accuracy: 0.9969
# Epoch 79/80
# 1378/1378 [==============================] - 9s 7ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0146 - val_accuracy: 0.9970
# Epoch 80/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0133 - val_accuracy: 0.9966

# %%
evaluate_model(CNN, x_test, y_test)
result_df = write_metrics_to_dataframe("CNN "+ config, calculate_metrics(y_test, CNN.predict(x_test)), result_df)
# Out:
# 703/703 [==============================] - 2s 2ms/step
# Accuracy: 0.7579583852036279
# Precision: 0.7837834167567318
# Recall: 0.7579583852036279
# F1-score: 0.7288879917605126
#
#
#                precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79      9684
#            1       0.92      0.85      0.88      7460
#            2       0.61      0.56      0.58      2421
#            3       0.89      0.15      0.26      2727
#            4       0.75      0.06      0.11       200
#
#     accuracy                           0.76     22492
#    macro avg       0.77      0.51      0.53     22492
# weighted avg       0.78      0.76      0.73     22492
# Class: 0
# False Positive Rate: 0.07622143006919689
# False Negative Rate: 0.07507228418009088
#
# Class: 1
# False Positive Rate: 0.07351344446573417
# False Negative Rate: 0.15428954423592492
#
# Class: 2
# False Positive Rate: 0.05267570900123304
# False Negative Rate: 0.44114002478314746
#
# Class: 3
# False Positive Rate: 0.1048951048951049
# False Negative Rate: 0.847084708470847
#
# Class: 4
# False Positive Rate: 0.008364477665064958
# False Negative Rate: 0.94
#
# 703/703 [==============================] - 2s 3ms/step
# <ipython-input-13-762dc581f4ba>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(metrics_dict, ignore_index=True)

# %% [markdown]
# ### cnn lstm

# %%
cnn_lstm = Sequential()
cnn_lstm.add(Dense(32, activation='relu', input_shape=(x_train.shape[1], 1)))
cnn_lstm.add(Conv1D(128, kernel_size=3, activation='relu'))
cnn_lstm.add(MaxPooling1D(pool_size=2))
cnn_lstm.add(LSTM(128, return_sequences=True))
cnn_lstm.add(Dropout(0.3))
cnn_lstm.add(Flatten())
cnn_lstm.add(Dense(128, activation='relu'))
cnn_lstm.add(Dense(5, activation='sigmoid'))
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
# Compile the cnn_lstm
cnn_lstm.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

cnn_lstm.summary()
# Train the cnn_lstm
history2 = cnn_lstm.fit(x_train, y_train, epochs=80, validation_data=(x_val,y_val),batch_size = 64)
evaluate_model(cnn_lstm, x_test, y_test)
result_df = write_metrics_to_dataframe("cnn_lstm "+config, calculate_metrics(y_test, cnn_lstm.predict(x_test)), result_df)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 116, 32)           64
#
#  conv1d_4 (Conv1D)           (None, 114, 128)          12416
#
#  max_pooling1d_2 (MaxPooling  (None, 57, 128)          0
#  1D)
#
#  lstm (LSTM)                 (None, 57, 128)           131584
#
#  dropout_3 (Dropout)         (None, 57, 128)           0
#
#  flatten_1 (Flatten)         (None, 7296)              0
#
#  dense_3 (Dense)             (None, 128)               934016
#
#  dense_4 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 1,078,725
# Trainable params: 1,078,725
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 1378/1378 [==============================] - 17s 9ms/step - loss: 0.0945 - accuracy: 0.9706 - val_loss: 0.0563 - val_accuracy: 0.9839
# Epoch 2/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0331 - accuracy: 0.9887 - val_loss: 0.0278 - val_accuracy: 0.9905
# Epoch 3/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0226 - accuracy: 0.9921 - val_loss: 0.0216 - val_accuracy: 0.9932
# Epoch 4/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 0.0179 - val_accuracy: 0.9951
# Epoch 5/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0149 - accuracy: 0.9949 - val_loss: 0.0196 - val_accuracy: 0.9936
# Epoch 6/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0177 - val_accuracy: 0.9942
# Epoch 7/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0170 - val_accuracy: 0.9952
# Epoch 8/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.0180 - val_accuracy: 0.9949
# Epoch 9/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0148 - val_accuracy: 0.9955
# Epoch 10/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0133 - val_accuracy: 0.9960
# Epoch 11/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0146 - val_accuracy: 0.9956
# Epoch 12/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0123 - val_accuracy: 0.9963
# Epoch 13/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0132 - val_accuracy: 0.9956
# Epoch 14/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0153 - val_accuracy: 0.9951
# Epoch 15/80
# 1378/1378 [==============================] - 14s 10ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0135 - val_accuracy: 0.9961
# Epoch 16/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0123 - val_accuracy: 0.9962
# Epoch 17/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 0.0104 - val_accuracy: 0.9967
# Epoch 18/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0157 - val_accuracy: 0.9956
# Epoch 19/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0114 - val_accuracy: 0.9965
# Epoch 20/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0116 - val_accuracy: 0.9965
# Epoch 21/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0131 - val_accuracy: 0.9961
# Epoch 22/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0126 - val_accuracy: 0.9966
# Epoch 23/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0131 - val_accuracy: 0.9963
# Epoch 24/80
# 1378/1378 [==============================] - 14s 10ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0112 - val_accuracy: 0.9963
# Epoch 25/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0127 - val_accuracy: 0.9965
# Epoch 26/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0119 - val_accuracy: 0.9966
# Epoch 27/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0132 - val_accuracy: 0.9962
# Epoch 28/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0141 - val_accuracy: 0.9960
# Epoch 29/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0146 - val_accuracy: 0.9960
# Epoch 30/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0107 - val_accuracy: 0.9967
# Epoch 31/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0191 - val_accuracy: 0.9951
# Epoch 32/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.0128 - val_accuracy: 0.9967
# Epoch 33/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 0.0171 - val_accuracy: 0.9963
# Epoch 34/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0047 - accuracy: 0.9981 - val_loss: 0.0143 - val_accuracy: 0.9966
# Epoch 35/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0125 - val_accuracy: 0.9966
# Epoch 36/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0117 - val_accuracy: 0.9970
# Epoch 37/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0121 - val_accuracy: 0.9967
# Epoch 38/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0112 - val_accuracy: 0.9972
# Epoch 39/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.0123 - val_accuracy: 0.9967
# Epoch 40/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0153 - val_accuracy: 0.9967
# Epoch 41/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0042 - accuracy: 0.9984 - val_loss: 0.0116 - val_accuracy: 0.9969
# Epoch 42/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0156 - val_accuracy: 0.9961
# Epoch 43/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0147 - val_accuracy: 0.9967
# Epoch 44/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0143 - val_accuracy: 0.9965
# Epoch 45/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0170 - val_accuracy: 0.9965
# Epoch 46/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0134 - val_accuracy: 0.9965
# Epoch 47/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.0143 - val_accuracy: 0.9968
# Epoch 48/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.0127 - val_accuracy: 0.9967
# Epoch 49/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0158 - val_accuracy: 0.9968
# Epoch 50/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0130 - val_accuracy: 0.9968
# Epoch 51/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0170 - val_accuracy: 0.9968
# Epoch 52/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0179 - val_accuracy: 0.9965
# Epoch 53/80
# 1378/1378 [==============================] - 13s 10ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0129 - val_accuracy: 0.9970
# Epoch 54/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0039 - accuracy: 0.9984 - val_loss: 0.0133 - val_accuracy: 0.9969
# Epoch 55/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.0137 - val_accuracy: 0.9967
# Epoch 56/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0125 - val_accuracy: 0.9968
# Epoch 57/80
# 1378/1378 [==============================] - 13s 10ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0135 - val_accuracy: 0.9970
# Epoch 58/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.0170 - val_accuracy: 0.9968
# Epoch 59/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0135 - val_accuracy: 0.9970
# Epoch 60/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.0142 - val_accuracy: 0.9967
# Epoch 61/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0034 - accuracy: 0.9985 - val_loss: 0.0153 - val_accuracy: 0.9971
# Epoch 62/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.0147 - val_accuracy: 0.9968
# Epoch 63/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.0180 - val_accuracy: 0.9963
# Epoch 64/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0162 - val_accuracy: 0.9966
# Epoch 65/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0195 - val_accuracy: 0.9964
# Epoch 66/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0152 - val_accuracy: 0.9970
# Epoch 67/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9969
# Epoch 68/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0166 - val_accuracy: 0.9966
# Epoch 69/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0128 - val_accuracy: 0.9971
# Epoch 70/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0149 - val_accuracy: 0.9970
# Epoch 71/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0143 - val_accuracy: 0.9969
# Epoch 72/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.0130 - val_accuracy: 0.9972
# Epoch 73/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0187 - val_accuracy: 0.9969
# Epoch 74/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9969
# Epoch 75/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0148 - val_accuracy: 0.9970
# Epoch 76/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0158 - val_accuracy: 0.9970
# Epoch 77/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0173 - val_accuracy: 0.9967
# Epoch 78/80
# 1378/1378 [==============================] - 12s 9ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0133 - val_accuracy: 0.9971
# Epoch 79/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0141 - val_accuracy: 0.9971
# Epoch 80/80
# 1378/1378 [==============================] - 13s 9ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0153 - val_accuracy: 0.9967
# 703/703 [==============================] - 3s 3ms/step
# Accuracy: 0.7372399075226748
# Precision: 0.7902717577532185
# Recall: 0.7372399075226748
# F1-score: 0.7118758517684282
#
#
#                precision    recall  f1-score   support
#
#            0       0.65      0.92      0.76      9684
#            1       0.96      0.78      0.86      7460
#            2       0.64      0.57      0.60      2421
#            3       0.98      0.16      0.27      2727
#            4       0.73      0.08      0.14       200
#
#     accuracy                           0.74     22492
#    macro avg       0.79      0.50      0.53     22492
# weighted avg       0.79      0.74      0.71     22492
# Class: 0
# False Positive Rate: 0.08384269403759659
# False Negative Rate: 0.07507228418009088
#
# Class: 1
# False Positive Rate: 0.1008464770720419
# False Negative Rate: 0.22198391420911529
#
# Class: 2
# False Positive Rate: 0.0514835920613087
# False Negative Rate: 0.432878975629905
#
# Class: 3
# False Positive Rate: 0.10408163265306122
# False Negative Rate: 0.8415841584158416
#
# Class: 4
# False Positive Rate: 0.00818869603916333
# False Negative Rate: 0.92
#
# 703/703 [==============================] - 2s 3ms/step
# <ipython-input-13-762dc581f4ba>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(metrics_dict, ignore_index=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Assuming you have true labels (y_true) and predicted probabilities (y_pred_prob)
# y_true: true labels of the test data (multi-class labels)
# y_pred_prob: predicted probabilities of each class
y_pred_prob = cnn_lstm.predict(x_test)
# Binarize the true labels (one-hot encoding)
y_true_bin = label_binarize(y_test, classes=np.unique(y_test))

# Compute the ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = y_true_bin.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curves for each class
plt.figure()

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='Class %d (AUC = %0.2f)' % (i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line representing random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 703/703 [==============================] - 3s 4ms/step

# %% [markdown]
# ### LSTM

# %%
lstm = Sequential()
lstm.add(Dense(32, activation='relu', input_shape=(x_train.shape[1],1)))
lstm.add(Dense(128, activation ='relu'))
lstm.add(LSTM(128, return_sequences=False))
lstm.add(Dense(64, activation='relu'))
lstm.add(Dense(128, activation='relu'))
lstm.add(Dropout(0.5))
lstm.add(Dense(5, activation='sigmoid'))

lstm.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
lstm.summary()

# Train the lstm
history3 = lstm.fit(x_train, y_train, epochs=80, validation_data=(x_val,y_val),batch_size = 64)

print("LSTM Classification report")
evaluate_model(lstm, x_test, y_test)
result_df = write_metrics_to_dataframe("lstm "+config, calculate_metrics(y_test, lstm.predict(x_test)), result_df)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 116, 32)           64
#
#  dense_6 (Dense)             (None, 116, 128)          4224
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 128)               8320
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 153,093
# Trainable params: 153,093
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 1378/1378 [==============================] - 19s 12ms/step - loss: 0.3787 - accuracy: 0.8853 - val_loss: 0.1821 - val_accuracy: 0.9500
# Epoch 2/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.3761 - accuracy: 0.8915 - val_loss: 0.4892 - val_accuracy: 0.8531
# Epoch 3/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.4901 - accuracy: 0.8557 - val_loss: 0.4899 - val_accuracy: 0.8531
# Epoch 4/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.4871 - accuracy: 0.8555 - val_loss: 0.4760 - val_accuracy: 0.8531
# Epoch 5/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.4173 - accuracy: 0.8663 - val_loss: 0.2910 - val_accuracy: 0.8900
# Epoch 6/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.3410 - accuracy: 0.8925 - val_loss: 0.1969 - val_accuracy: 0.9501
# Epoch 7/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.1805 - accuracy: 0.9512 - val_loss: 0.1183 - val_accuracy: 0.9684
# Epoch 8/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.1382 - accuracy: 0.9613 - val_loss: 0.0966 - val_accuracy: 0.9711
# Epoch 9/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.1012 - accuracy: 0.9708 - val_loss: 0.0791 - val_accuracy: 0.9742
# Epoch 10/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0941 - accuracy: 0.9720 - val_loss: 0.1227 - val_accuracy: 0.9635
# Epoch 11/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0912 - accuracy: 0.9732 - val_loss: 0.0820 - val_accuracy: 0.9726
# Epoch 12/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0772 - accuracy: 0.9761 - val_loss: 0.0705 - val_accuracy: 0.9762
# Epoch 13/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0816 - accuracy: 0.9749 - val_loss: 0.0599 - val_accuracy: 0.9793
# Epoch 14/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0669 - accuracy: 0.9787 - val_loss: 0.0612 - val_accuracy: 0.9776
# Epoch 15/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0573 - accuracy: 0.9818 - val_loss: 0.0495 - val_accuracy: 0.9823
# Epoch 16/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.0545 - accuracy: 0.9828 - val_loss: 0.0661 - val_accuracy: 0.9822
# Epoch 17/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0543 - accuracy: 0.9838 - val_loss: 0.0409 - val_accuracy: 0.9879
# Epoch 18/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0496 - accuracy: 0.9858 - val_loss: 0.0510 - val_accuracy: 0.9855
# Epoch 19/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0434 - accuracy: 0.9883 - val_loss: 0.0503 - val_accuracy: 0.9857
# Epoch 20/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0434 - accuracy: 0.9884 - val_loss: 0.0749 - val_accuracy: 0.9800
# Epoch 21/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0423 - accuracy: 0.9880 - val_loss: 0.0389 - val_accuracy: 0.9896
# Epoch 22/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.0498 - accuracy: 0.9860 - val_loss: 0.0603 - val_accuracy: 0.9836
# Epoch 23/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0349 - accuracy: 0.9908 - val_loss: 0.0328 - val_accuracy: 0.9910
# Epoch 24/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0370 - accuracy: 0.9900 - val_loss: 0.0424 - val_accuracy: 0.9891
# Epoch 25/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0353 - accuracy: 0.9905 - val_loss: 0.0408 - val_accuracy: 0.9881
# Epoch 26/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0335 - accuracy: 0.9913 - val_loss: 0.0310 - val_accuracy: 0.9915
# Epoch 27/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0340 - accuracy: 0.9913 - val_loss: 0.0377 - val_accuracy: 0.9893
# Epoch 28/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0532 - accuracy: 0.9852 - val_loss: 0.0719 - val_accuracy: 0.9806
# Epoch 29/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0431 - accuracy: 0.9891 - val_loss: 0.0409 - val_accuracy: 0.9891
# Epoch 30/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0354 - accuracy: 0.9909 - val_loss: 0.0338 - val_accuracy: 0.9921
# Epoch 31/80
# 1378/1378 [==============================] - 19s 14ms/step - loss: 0.0352 - accuracy: 0.9912 - val_loss: 0.0340 - val_accuracy: 0.9912
# Epoch 32/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0336 - accuracy: 0.9910 - val_loss: 0.0311 - val_accuracy: 0.9915
# Epoch 33/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.0281 - accuracy: 0.9924 - val_loss: 0.0339 - val_accuracy: 0.9918
# Epoch 34/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0273 - accuracy: 0.9931 - val_loss: 0.0373 - val_accuracy: 0.9918
# Epoch 35/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0303 - accuracy: 0.9920 - val_loss: 0.0386 - val_accuracy: 0.9910
# Epoch 36/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0296 - accuracy: 0.9925 - val_loss: 0.0283 - val_accuracy: 0.9922
# Epoch 37/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0253 - accuracy: 0.9935 - val_loss: 0.0453 - val_accuracy: 0.9868
# Epoch 38/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0305 - accuracy: 0.9917 - val_loss: 0.0296 - val_accuracy: 0.9922
# Epoch 39/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0264 - accuracy: 0.9929 - val_loss: 0.0277 - val_accuracy: 0.9924
# Epoch 40/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0256 - accuracy: 0.9933 - val_loss: 0.0261 - val_accuracy: 0.9933
# Epoch 41/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0255 - accuracy: 0.9931 - val_loss: 0.0274 - val_accuracy: 0.9929
# Epoch 42/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.0272 - val_accuracy: 0.9931
# Epoch 43/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0252 - accuracy: 0.9932 - val_loss: 0.0279 - val_accuracy: 0.9923
# Epoch 44/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0293 - accuracy: 0.9918 - val_loss: 0.0326 - val_accuracy: 0.9908
# Epoch 45/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.0358 - val_accuracy: 0.9895
# Epoch 46/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0270 - val_accuracy: 0.9927
# Epoch 47/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0225 - accuracy: 0.9939 - val_loss: 0.0218 - val_accuracy: 0.9941
# Epoch 48/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0231 - accuracy: 0.9941 - val_loss: 0.0292 - val_accuracy: 0.9919
# Epoch 49/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.0242 - val_accuracy: 0.9935
# Epoch 50/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 0.0441 - val_accuracy: 0.9858
# Epoch 51/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0321 - accuracy: 0.9916 - val_loss: 0.0270 - val_accuracy: 0.9927
# Epoch 52/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.0205 - val_accuracy: 0.9939
# Epoch 53/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0414 - val_accuracy: 0.9875
# Epoch 54/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0231 - accuracy: 0.9938 - val_loss: 0.0308 - val_accuracy: 0.9911
# Epoch 55/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0207 - accuracy: 0.9942 - val_loss: 0.0313 - val_accuracy: 0.9925
# Epoch 56/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0178 - accuracy: 0.9951 - val_loss: 0.0233 - val_accuracy: 0.9940
# Epoch 57/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0229 - val_accuracy: 0.9931
# Epoch 58/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0198 - accuracy: 0.9946 - val_loss: 0.0462 - val_accuracy: 0.9889
# Epoch 59/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0263 - accuracy: 0.9933 - val_loss: 0.0251 - val_accuracy: 0.9926
# Epoch 60/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0236 - val_accuracy: 0.9941
# Epoch 61/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0175 - accuracy: 0.9951 - val_loss: 0.0207 - val_accuracy: 0.9936
# Epoch 62/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.0238 - val_accuracy: 0.9936
# Epoch 63/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0222 - accuracy: 0.9940 - val_loss: 0.0232 - val_accuracy: 0.9945
# Epoch 64/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 0.0605 - val_accuracy: 0.9844
# Epoch 65/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0209 - accuracy: 0.9940 - val_loss: 0.0235 - val_accuracy: 0.9942
# Epoch 66/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0174 - accuracy: 0.9952 - val_loss: 0.0200 - val_accuracy: 0.9948
# Epoch 67/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0164 - accuracy: 0.9954 - val_loss: 0.0215 - val_accuracy: 0.9949
# Epoch 68/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0187 - accuracy: 0.9950 - val_loss: 0.0270 - val_accuracy: 0.9915
# Epoch 69/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.1018 - val_accuracy: 0.9819
# Epoch 70/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.0224 - val_accuracy: 0.9946
# Epoch 71/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.0223 - val_accuracy: 0.9940
# Epoch 72/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.0192 - val_accuracy: 0.9947
# Epoch 73/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.0172 - val_accuracy: 0.9954
# Epoch 74/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0338 - accuracy: 0.9926 - val_loss: 0.0362 - val_accuracy: 0.9903
# Epoch 75/80
# 1378/1378 [==============================] - 16s 12ms/step - loss: 0.0216 - accuracy: 0.9943 - val_loss: 0.0220 - val_accuracy: 0.9935
# Epoch 76/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0174 - accuracy: 0.9951 - val_loss: 0.0232 - val_accuracy: 0.9936
# Epoch 77/80
# 1378/1378 [==============================] - 15s 11ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.0244 - val_accuracy: 0.9939
# Epoch 78/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.0267 - val_accuracy: 0.9930
# Epoch 79/80
# 1378/1378 [==============================] - 16s 11ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 0.0206 - val_accuracy: 0.9952
# Epoch 80/80
# 1378/1378 [==============================] - 18s 13ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.0202 - val_accuracy: 0.9949
# LSTM Classification report
# 703/703 [==============================] - 3s 4ms/step
# Accuracy: 0.7363062422194558
# Precision: 0.7551009379554361
# Recall: 0.7363062422194558
# F1-score: 0.7067940482628344
#
#
#                precision    recall  f1-score   support
#
#            0       0.67      0.93      0.78      9684
#            1       0.93      0.78      0.85      7460
#            2       0.63      0.59      0.61      2421
#            3       0.69      0.13      0.22      2727
#            4       1.00      0.01      0.03       200
#
#     accuracy                           0.74     22492
#    macro avg       0.78      0.49      0.50     22492
# weighted avg       0.76      0.74      0.71     22492
# Class: 0
# False Positive Rate: 0.07882534775888717
# False Negative Rate: 0.07372986369268897
#
# Class: 1
# False Positive Rate: 0.10228462343740378
# False Negative Rate: 0.22265415549597856
#
# Class: 2
# False Positive Rate: 0.04857397504456328
# False Negative Rate: 0.4052044609665427
#
# Class: 3
# False Positive Rate: 0.10815973801510052
# False Negative Rate: 0.8720205353868721
#
# Class: 4
# False Positive Rate: 0.008759838143092178
# False Negative Rate: 0.985
#
# 703/703 [==============================] - 3s 4ms/step
# <ipython-input-13-762dc581f4ba>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(metrics_dict, ignore_index=True)

# %% [markdown]
# ### DNN

# %%
DNN = Sequential()
DNN.add(Dense(112, input_shape=(x_train.shape[1],), activation='relu'))
DNN.add(Dense(64, activation='relu'))
DNN.add(Dense(128, activation='relu'))
DNN.add(Dropout(0.5))
DNN.add(Dense(64, activation='relu'))
DNN.add(Dense(5, activation='sigmoid'))

DNN.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
DNN.summary()

# Train the DNN
history4 = DNN.fit(x_train, y_train, epochs=80, validation_data=(x_val,y_val),batch_size = 64)

print("DNN Classification report")
evaluate_model(DNN, x_test, y_test)
result_df = write_metrics_to_dataframe("DNN "+config, calculate_metrics(y_test, DNN.predict(x_test)), result_df)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 112)               13104
#
#  dense_11 (Dense)            (None, 64)                7232
#
#  dense_12 (Dense)            (None, 128)               8320
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 37,237
# Trainable params: 37,237
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/80
# 1378/1378 [==============================] - 9s 5ms/step - loss: 0.0880 - accuracy: 0.9721 - val_loss: 0.0354 - val_accuracy: 0.9898
# Epoch 2/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0321 - accuracy: 0.9893 - val_loss: 0.0357 - val_accuracy: 0.9881
# Epoch 3/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0243 - accuracy: 0.9918 - val_loss: 0.0269 - val_accuracy: 0.9921
# Epoch 4/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.0258 - val_accuracy: 0.9919
# Epoch 5/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0255 - val_accuracy: 0.9931
# Epoch 6/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0167 - accuracy: 0.9942 - val_loss: 0.0207 - val_accuracy: 0.9941
# Epoch 7/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.0226 - val_accuracy: 0.9925
# Epoch 8/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0218 - val_accuracy: 0.9942
# Epoch 9/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0137 - accuracy: 0.9953 - val_loss: 0.0197 - val_accuracy: 0.9943
# Epoch 10/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.0241 - val_accuracy: 0.9936
# Epoch 11/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0244 - val_accuracy: 0.9936
# Epoch 12/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0219 - val_accuracy: 0.9940
# Epoch 13/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0192 - val_accuracy: 0.9949
# Epoch 14/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.0230 - val_accuracy: 0.9937
# Epoch 15/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0109 - accuracy: 0.9961 - val_loss: 0.0197 - val_accuracy: 0.9951
# Epoch 16/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0203 - val_accuracy: 0.9947
# Epoch 17/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0209 - val_accuracy: 0.9947
# Epoch 18/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0204 - val_accuracy: 0.9954
# Epoch 19/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0191 - val_accuracy: 0.9956
# Epoch 20/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0094 - accuracy: 0.9964 - val_loss: 0.0266 - val_accuracy: 0.9949
# Epoch 21/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0200 - val_accuracy: 0.9951
# Epoch 22/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0221 - val_accuracy: 0.9948
# Epoch 23/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0239 - val_accuracy: 0.9947
# Epoch 24/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0246 - val_accuracy: 0.9950
# Epoch 25/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0254 - val_accuracy: 0.9945
# Epoch 26/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0203 - val_accuracy: 0.9949
# Epoch 27/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0199 - val_accuracy: 0.9957
# Epoch 28/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0195 - val_accuracy: 0.9954
# Epoch 29/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0183 - val_accuracy: 0.9954
# Epoch 30/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0214 - val_accuracy: 0.9960
# Epoch 31/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0258 - val_accuracy: 0.9946
# Epoch 32/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0266 - val_accuracy: 0.9947
# Epoch 33/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0258 - val_accuracy: 0.9961
# Epoch 34/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0210 - val_accuracy: 0.9948
# Epoch 35/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0206 - val_accuracy: 0.9959
# Epoch 36/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0223 - val_accuracy: 0.9962
# Epoch 37/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0192 - val_accuracy: 0.9956
# Epoch 38/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0274 - val_accuracy: 0.9964
# Epoch 39/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0291 - val_accuracy: 0.9944
# Epoch 40/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0218 - val_accuracy: 0.9963
# Epoch 41/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0304 - val_accuracy: 0.9960
# Epoch 42/80
# 1378/1378 [==============================] - 6s 5ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0290 - val_accuracy: 0.9953
# Epoch 43/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0215 - val_accuracy: 0.9961
# Epoch 44/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0213 - val_accuracy: 0.9958
# Epoch 45/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0241 - val_accuracy: 0.9959
# Epoch 46/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0300 - val_accuracy: 0.9963
# Epoch 47/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0247 - val_accuracy: 0.9968
# Epoch 48/80
# 1378/1378 [==============================] - 6s 5ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0275 - val_accuracy: 0.9962
# Epoch 49/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0229 - val_accuracy: 0.9969
# Epoch 50/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0289 - val_accuracy: 0.9955
# Epoch 51/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0253 - val_accuracy: 0.9961
# Epoch 52/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0274 - val_accuracy: 0.9958
# Epoch 53/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0265 - val_accuracy: 0.9967
# Epoch 54/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0290 - val_accuracy: 0.9960
# Epoch 55/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0320 - val_accuracy: 0.9953
# Epoch 56/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0265 - val_accuracy: 0.9955
# Epoch 57/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0325 - val_accuracy: 0.9958
# Epoch 58/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0248 - val_accuracy: 0.9963
# Epoch 59/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0322 - val_accuracy: 0.9966
# Epoch 60/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0338 - val_accuracy: 0.9958
# Epoch 61/80
# 1378/1378 [==============================] - 8s 6ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0327 - val_accuracy: 0.9968
# Epoch 62/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0354 - val_accuracy: 0.9966
# Epoch 63/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0324 - val_accuracy: 0.9965
# Epoch 64/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0312 - val_accuracy: 0.9957
# Epoch 65/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0265 - val_accuracy: 0.9967
# Epoch 66/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0352 - val_accuracy: 0.9961
# Epoch 67/80
# 1378/1378 [==============================] - 6s 5ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0346 - val_accuracy: 0.9958
# Epoch 68/80
# 1378/1378 [==============================] - 6s 5ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0279 - val_accuracy: 0.9966
# Epoch 69/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0266 - val_accuracy: 0.9963
# Epoch 70/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0336 - val_accuracy: 0.9965
# Epoch 71/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0431 - val_accuracy: 0.9962
# Epoch 72/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0403 - val_accuracy: 0.9966
# Epoch 73/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0307 - val_accuracy: 0.9964
# Epoch 74/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0410 - val_accuracy: 0.9961
# Epoch 75/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0366 - val_accuracy: 0.9964
# Epoch 76/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0398 - val_accuracy: 0.9957
# Epoch 77/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0393 - val_accuracy: 0.9958
# Epoch 78/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0396 - val_accuracy: 0.9966
# Epoch 79/80
# 1378/1378 [==============================] - 6s 4ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0360 - val_accuracy: 0.9963
# Epoch 80/80
# 1378/1378 [==============================] - 7s 5ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0353 - val_accuracy: 0.9968
# DNN Classification report
# 703/703 [==============================] - 1s 2ms/step
# Accuracy: 0.779966210208074
# Precision: 0.7862492172139053
# Recall: 0.779966210208074
# F1-score: 0.7499337476242589
#
#
#                precision    recall  f1-score   support
#
#            0       0.71      0.93      0.80      9684
#            1       0.90      0.86      0.88      7460
#            2       0.84      0.72      0.77      2421
#            3       0.74      0.14      0.23      2727
#            4       0.51      0.09      0.15       200
#
#     accuracy                           0.78     22492
#    macro avg       0.74      0.55      0.57     22492
# weighted avg       0.79      0.78      0.75     22492
# Class: 0
# False Positive Rate: 0.07282741738066095
# False Negative Rate: 0.07372986369268897
#
# Class: 1
# False Positive Rate: 0.06700189381571214
# False Negative Rate: 0.13753351206434317
#
# Class: 2
# False Positive Rate: 0.03330884153808474
# False Negative Rate: 0.2808756712102437
#
# Class: 3
# False Positive Rate: 0.10678374812320851
# False Negative Rate: 0.8606527319398607
#
# Class: 4
# False Positive Rate: 0.008104377254308234
# False Negative Rate: 0.91
#
# 703/703 [==============================] - 1s 2ms/step
# <ipython-input-13-762dc581f4ba>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(metrics_dict, ignore_index=True)

# %%
import matplotlib.pyplot as plt

def plot_metrics_comparison(histories, model_names):
    # Creating subplots for accuracy and loss
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))

    # Plotting training and validation accuracy
    axs[0, 0].set_title('Training Accuracy')
    axs[0, 0].set_xlabel('Epochs')
    axs[0, 0].set_ylabel('Accuracy')

    axs[0, 1].set_title('Validation Accuracy')
    axs[0, 1].set_xlabel('Epochs')
    axs[0, 1].set_ylabel('Accuracy')

    # Plotting training and validation loss
    axs[1, 0].set_title('Training Loss')
    axs[1, 0].set_xlabel('Epochs')
    axs[1, 0].set_ylabel('Loss')

    axs[1, 1].set_title('Validation Loss')
    axs[1, 1].set_xlabel('Epochs')
    axs[1, 1].set_ylabel('Loss')

    # Plotting metrics for each model
    for i, history in enumerate(histories):
        model_name = model_names[i]
        train_accuracy = history.history['accuracy']
        val_accuracy = history.history['val_accuracy']
        train_loss = history.history['loss']
        val_loss = history.history['val_loss']

        # Plotting training and validation accuracy
        axs[0, 0].plot(train_accuracy, label=model_name)
        axs[0, 1].plot(val_accuracy, label=model_name)

        # Plotting training and validation loss
        axs[1, 0].plot(train_loss, label=model_name)
        axs[1, 1].plot(val_loss, label=model_name)

    # Adjusting spacing between subplots
    plt.tight_layout()

    # Adding legends
    axs[0, 0].legend()
    axs[0, 1].legend()
    axs[1, 0].legend()
    axs[1, 1].legend()

    # Display the plot
    plt.show()

# %%
histories = [history,history2, history3, history4]
model_names = ['CNN', 'CNN-LSTM', 'LSTM', 'DNN']
plot_metrics_comparison(histories, model_names)

# %%
result_df.to_csv("/content/drive/MyDrive/Colab Notebooks/"+config+" multi .txt", index = False)
